# %%
import urllib.request
from bs4 import BeautifulSoup as soup
#import requests
import re
import pandas as pd
import numpy as np
link = 'https://www.ewrc-results.com/results/81302-rally-adriatico-2023/?s='
startat, no_ss=423017, int(9)
#monte_23 = pd.DataFrame(columns=['Pos.', 'Pilote / Co-pilote', 'Voiture', '#', 'Temps', 'Écart'])
rally_23 = []
canceled = []

stages = [number for number in range(no_ss)]

if canceled:
    for j in canceled: stages.remove(j-1)

# %%
#for ss in range(0,(no_ss)):
for ss in stages:
    val= startat + ss
    ss_a = str(val)
    my_url11 = link + ss_a
    #print(my_url11)
    req = urllib.request.Request(my_url11, headers={'User-Agent': 'Mozilla/5.0'})
    uClient11 = urllib.request.urlopen(req)
    page_html11 = uClient11.read()
    uClient11.close()
    data = pd.read_html(page_html11)[0]
    data.columns=['Pos.', 'No', 'Crew', 'Gr/Cl','ss_time', 'Diff', 'Speed']
    data['ss']=ss+1
    equal = '=' in data['Pos.'].unique()
    if equal:
        data['Pos.'] = data['Pos.'].replace('=', method='ffill')
        data['Pos.'] = data['Pos.'].astype(str).astype(float)
    #print(data.dtypes)
    #print(data)
    rally_23.append(data)
# Out:
# /tmp/ipykernel_61530/703784724.py:14: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   equal = '=' in data['Pos.'].unique()
# /tmp/ipykernel_61530/703784724.py:14: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   equal = '=' in data['Pos.'].unique()
# /tmp/ipykernel_61530/703784724.py:14: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   equal = '=' in data['Pos.'].unique()
# /tmp/ipykernel_61530/703784724.py:14: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   equal = '=' in data['Pos.'].unique()

# %%
rally2023_stages = pd.concat(rally_23, axis=0)
rally2023_stages.columns=['Pos.', 'No', 'Crew', 'Gr/Cl','ss_time', 'Diff', 'Speed', 'ss']
rally2023_stages['Pos.'] = rally2023_stages['Pos.'].astype(int)
rally2023_stages.to_csv('Adriatico2023_st.csv', index=False)
#print(rally2023_stages)
#print(rally2023_stages.dtypes)

dataview = rally2023_stages.drop(['Diff','Speed','Pos.'], axis=1)
dataview = dataview.fillna('-')
data_view2 = dataview.set_index(['No', 'Crew', 'Gr/Cl','ss'], drop=True).unstack('ss')
data_view2 = data_view2.fillna('-')
data_view2.to_csv('Adriatico2023_comp.csv')
print(dataview)
# Out:
#      No                                               Crew              Gr/Cl  \
# 0    #9  Todeschini F.  - De Castelli S. Hyundai i20 N ...          R5/Rally2
# 1    #3  Gryazin Nikolay  - Aleksandrov K. Škoda Fabia ...          R5/Rally2
# 2    #1  Andreucci Paolo  - Briani Rudy Škoda Fabia Ral...  R5/Rally2 Over 55
# 3    #2  Ciuffi Tommaso  - Cigni Pietro Škoda Fabia Ral...          R5/Rally2
# 4    #8  Oldrati Enrico  - De Guio Elia Škoda Fabia Ral...          R5/Rally2
# ..  ...                                                ...                ...
# 42  #78   Ongaro Germano  - Toffano Mattia Renault Clio RS                 N3
# 43  #79  Cerroni Wiliam  - Cicciarelli F. Renault Clio ...                 N3
# 44  #89     Lanci Maicol  - De Luca Fabio Citroën Saxo VTS                 N2
# 45  #91  Olevano Emmanuele  - De Filippi S. Suzuki Swif...        N2 Under 25
# 46  #88  Pregheffi M.  - Lamberti Zanardi A. Mini Cooper S           RSTB 1.6
#
#    ss_time  ss
# 0   6:23.8   1
# 1   6:24.9   1
# 2   6:29.6   1
# 3   6:35.0   1
# 4   6:37.8   1
# ..     ...  ..
# 42  5:27.0   9
# 43  5:28.5   9
# 44  6:03.9   9
# 45  6:13.4   9
# 46  7:38.4   9
#
# [481 rows x 5 columns]

# %%
rally4 = rally2023_stages[rally2023_stages['Gr/Cl'].str.contains('Rally4')]
rally4 = rally4.drop(['Pos.','Diff','Speed'], axis=1)
stages = rally4.sort_values(by=['ss','ss_time'])
stages['cou']= stages.groupby(['ss']).cumcount()+1
stages
# Out:
#      No                                               Crew            Gr/Cl  \
# 18  #51  Fontana Matteo  - Arnaboldi A. Peugeot 208 Rally4  Rally4 Under 25
# 20  #49  Cogni Giorgio  - Colapietro Andrea Peugeot 208...           Rally4
# 21  #54  Pesavento Davide  - Zaramella M. Peugeot 208 R...  Rally4 Under 25
# 25  #52  Marchioro Nicolò  - Marchetti M. Peugeot 208 R...           Rally4
# 26  #55  Ancillotti L.  - Ancillotti C. Peugeot 208 Rally4           Rally4
# ..  ...                                                ...              ...
# 32  #72  Leuratti Giorgio  - Del Rio L. Peugeot 208 Rally4           Rally4
# 33  #58  Brancadori Alberto  - Pollini C. Peugeot 208 R...   Rally4 Over 55
# 36  #73  Rousopoulos Christos  - Moukas E. Peugeot 208 ...           Rally4
# 38  #76   Ricciardi Franco  - Bartolucci M. Peugeot 208 R2        Rally4/R2
# 40  #75             Frare Luca  - Rücker S. Peugeot 208 R2        Rally4/R2
#
#    ss_time  ss  cou
# 18  7:03.4   1    1
# 20  7:04.4   1    2
# 21  7:06.7   1    3
# 25  7:16.3   1    4
# 26  7:16.5   1    5
# ..     ...  ..  ...
# 32  4:46.1   9   10
# 33  4:46.7   9   11
# 36  4:53.4   9   12
# 38  4:57.6   9   13
# 40  5:06.5   9   14
#
# [127 rows x 6 columns]

# %%
stages = stages.drop('Gr/Cl', axis=1)
#stages['cou'] = stages['cou'].astype(int)
stages2 = stages.set_index(['No', 'Crew', 'ss'], drop=True).unstack('ss', fill_value="_")
stages2 = stages2.fillna('-')
#stages2['cou'] = stages2['cou'].astype(int)
stages2.to_csv('Rally4_Adriatico_2023.csv', index=False)
stages2
# Out:
#                                                        ss_time          \
# ss                                                           1       2
# No  Crew
# #49 Cogni Giorgio  - Colapietro Andrea Peugeot 208 ...  7:04.4  6:35.8
