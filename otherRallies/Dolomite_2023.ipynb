# %%
import urllib.request
from bs4 import BeautifulSoup as soup
#import requests
import re
import pandas as pd
import numpy as np
link = 'https://www.ewrc-results.com/results/81319-dolomiti-brenta-rally-2023/?s='
startat, no_ss=420036, int(7)
#monte_23 = pd.DataFrame(columns=['Pos.', 'Pilote / Co-pilote', 'Voiture', '#', 'Temps', 'Écart'])
rally_23 = []
canceled = []

stages = [number for number in range(no_ss)]

if canceled:
    for j in canceled: stages.remove(j-1)

# %%
#for ss in range(0,(no_ss)):
for ss in stages:
    val= startat + ss
    ss_a = str(val)
    my_url11 = link + ss_a
    #print(my_url11)
    req = urllib.request.Request(my_url11, headers={'User-Agent': 'Mozilla/5.0'})
    uClient11 = urllib.request.urlopen(req)
    page_html11 = uClient11.read()
    uClient11.close()
    data = pd.read_html(page_html11)[0]
    data.columns=['Pos.', 'No', 'Crew', 'Gr/Cl','ss_time', 'Diff', 'Speed']
    data['ss']=ss+1
    equal = '=' in data['Pos.'].unique()
    if equal:
        data['Pos.'] = data['Pos.'].replace('=', method='ffill')
        data['Pos.'] = data['Pos.'].astype(str).astype(float)
    #print(data.dtypes)
    #print(data)
    rally_23.append(data)
# Out:
# /tmp/ipykernel_60881/703784724.py:14: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   equal = '=' in data['Pos.'].unique()
# /tmp/ipykernel_60881/703784724.py:14: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   equal = '=' in data['Pos.'].unique()
# /tmp/ipykernel_60881/703784724.py:14: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   equal = '=' in data['Pos.'].unique()
# /tmp/ipykernel_60881/703784724.py:14: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   equal = '=' in data['Pos.'].unique()
# /tmp/ipykernel_60881/703784724.py:14: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   equal = '=' in data['Pos.'].unique()
# /tmp/ipykernel_60881/703784724.py:14: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   equal = '=' in data['Pos.'].unique()

# %%
rally2023_stages = pd.concat(rally_23, axis=0)
rally2023_stages.columns=['Pos.', 'No', 'Crew', 'Gr/Cl','ss_time', 'Diff', 'Speed', 'ss']
rally2023_stages['Pos.'] = rally2023_stages['Pos.'].astype(int)
rally2023_stages.to_csv('Dolomite2023_st.csv', index=False)
#print(rally2023_stages)
#print(rally2023_stages.dtypes)

dataview = rally2023_stages.drop(['Diff','Speed','Pos.'], axis=1)
dataview = dataview.fillna('-')
data_view2 = dataview.set_index(['No', 'Crew', 'Gr/Cl','ss'], drop=True).unstack('ss')
data_view2 = data_view2.fillna('-')
data_view2.to_csv('Dolomite2023_comp.csv')
print(dataview)
# Out:
#      No                                               Crew              Gr/Cl  \
# 0    #6  Zanolli Alessandro  - Pozzo Denis Škoda Fabia ...          R5/Rally2
# 1    #4  Daprà Matteo  - Conci Mattias Škoda Fabia Rall...          R5/Rally2
# 2    #2       Battaglin A.  - Pagliarini S. Hyundai i20 R5  R5/Rally2 Over 55
# 3    #1  De Tisi Pietro  - Gasparotto Ivan Škoda Fabia ...          R5/Rally2
# 4    #5  Menegatti Paolo  - Rutigliano N. Škoda Fabia R...          R5/Rally2
# ..  ...                                                ...                ...
# 37  #45       Longo Marco  - Riva Roberto Suzuki Swift R1B       Ra5N Over 55
# 38  #46   Manera Luca  - Manera Francesca Suzuki Swift R1B       Ra5N Over 55
# 39  #49  De Mattè Bruno  - Compagno Paolo Citroën Saxo VTS                 N2
# 40  #50             Piras Sean  - Alongi Fabio Peugeot 106        N2 Under 25
# 41  #47  Campora Cristina  - Iuretig Miriam Peugeot 106...          A6 Female
#
#    ss_time  ss
# 0   4:20.5   1
# 1   4:20.7   1
# 2   4:21.4   1
# 3   4:22.1   1
# 4   4:22.6   1
# ..     ...  ..
# 37  5:07.6   7
# 38  5:08.3   7
# 39  5:15.9   7
# 40  5:29.8   7
# 41  5:45.1   7
#
# [315 rows x 5 columns]

# %%
rally4 = rally2023_stages[rally2023_stages['Gr/Cl'].str.contains('Rally4')]
rally4 = rally4.drop(['Pos.','Diff','Speed'], axis=1)
stages = rally4.sort_values(by=['ss','ss_time'])
stages['cou']= stages.groupby(['ss']).cumcount()+1
stages
# Out:
#      No                                               Crew           Gr/Cl  \
# 10  #24  Strabello Stefano  - Montavoci S. Peugeot 208 ...          Rally4
# 16  #30  Angi Simone  - Maddalozzo Jenny Peugeot 208 Ra...          Rally4
# 17  #25     Pagnan Alex  - Mondin Livio Peugeot 208 Rally4          Rally4
# 18  #22  Strabello Paolo  - Bianchi Davide Peugeot 208 ...  Rally4 Over 55
# 19  #31    Casagrande D.  - Franceschini L. Peugeot 208 R2       Rally4/R2
# ..  ...                                                ...             ...
# 21  #22  Strabello Paolo  - Bianchi Davide Peugeot 208 ...  Rally4 Over 55
# 28  #28  Ferrarol Maurizio  - Frigerio G. Renault Clio ...          Rally4
# 30  #33    Travaglini Luca  - Calliari Nico Peugeot 208 R2       Rally4/R2
# 32  #27  Vardanega Roger  - Pellegrino S. Peugeot 208 R...          Rally4
# 35  #34    Betta Armando  - Modenini Mattea Peugeot 208 R2       Rally4/R2
#
#    ss_time  ss  cou
# 10  4:41.3   1    1
# 16  4:47.2   1    2
# 17  4:47.5   1    3
# 18  4:48.1   1    4
# 19  4:48.3   1    5
# ..     ...  ..  ...
# 21  4:39.1   7    7
# 28  4:50.0   7    8
# 30  4:53.3   7    9
# 32  4:54.4   7   10
# 35  4:57.9   7   11
#
# [84 rows x 6 columns]

# %%
stages = stages.drop('Gr/Cl', axis=1)
#stages['cou'] = stages['cou'].astype(int)
stages2 = stages.set_index(['No', 'Crew', 'ss'], drop=True).unstack('ss', fill_value="_")
stages2 = stages2.fillna('-')
#stages2['cou'] = stages2['cou'].astype(int)
stages2.to_csv('Rally4_Dolomite_2023,csv')
stages2
# Out:
#                                                        ss_time          \
# ss                                                           1       2
# No  Crew
# #22 Strabello Paolo  - Bianchi Davide Peugeot 208 R...  4:48.1  7:32.4
# #23 Scalco Leonardo  - Toffano Mattia Peugeot 208 R...  4:55.2  7:21.6
