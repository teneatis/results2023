# %%
import urllib.request
from bs4 import BeautifulSoup as soup
#import requests
import re
import pandas as pd
import numpy as np
import dataframe_image as dfi
link = 'https://www.ewrc-results.com/results/80810-prealpi-master-show-2022/?s='
startat, no_ss=395319, int(4)
#monte_23 = pd.DataFrame(columns=['Pos.', 'Pilote / Co-pilote', 'Voiture', '#', 'Temps', 'Écart'])
rally_23 = []
canceled = []

stages = [number for number in range(no_ss)]

if canceled:
    for j in canceled: stages.remove(j-1)

# %%
#for ss in range(0,(no_ss)):
for ss in stages:
    val= startat + ss
    ss_a = str(val)
    my_url11 = link + ss_a
    #print(my_url11)
    req = urllib.request.Request(my_url11, headers={'User-Agent': 'Mozilla/5.0'})
    uClient11 = urllib.request.urlopen(req)
    page_html11 = uClient11.read()
    uClient11.close()
    data = pd.read_html(page_html11)[0]
    data.columns=['Pos.', 'No', 'Crew', 'Gr/Cl','ss_time', 'Diff', 'Speed']
    data['ss']=ss+1
    equal = '=' in data['Pos.'].unique()
    if equal:
        data['Pos.'] = data['Pos.'].replace('=', method='ffill')
        data['Pos.'] = data['Pos.'].astype(str).astype(float)
    #print(data.dtypes)
    #print(data)
    rally_23.append(data)

# %%
rally2023_stages = pd.concat(rally_23, axis=0)
rally2023_stages.columns=['Pos.', 'No', 'Crew', 'Gr/Cl','ss_time', 'Diff', 'Speed', 'ss']
rally2023_stages['Pos.'] = rally2023_stages['Pos.'].astype(int)
rally2023_stages.to_csv('Prealpi2022_st.csv', index=False)
#print(rally2023_stages)
#print(rally2023_stages.dtypes)

dataview = rally2023_stages.drop(['Diff','Speed','Pos.'], axis=1)
dataview = dataview.fillna('-')
data_view2 = dataview.set_index(['No', 'Crew', 'Gr/Cl','ss'], drop=True).unstack('ss')
data_view2 = data_view2.fillna('-')
data_view2.to_csv('Prealpi2022_comp.csv')
print(dataview)
# Out:
#        No                                               Crew        Gr/Cl  \
# 0      #5  Quilichini J.  - Buresi F. Škoda Fabia Rally2 evo    R5/Rally2
# 1     #11  Avbelj Boštjan  - Andrejka D. Škoda Fabia Rall...    R5/Rally2
# 2      #7    Vagnini Jader  - Musiari Martina Škoda Fabia R5    R5/Rally2
# 3      #1  Dalmazzini Andrea  - Albertini A. Hyundai i20 ...    R5/Rally2
# 4     #22  Sandrin Andrea  - Menegon Manuel Škoda Fabia R...    R5/Rally2
# ..    ...                                                ...          ...
# 98    #72  Todaro Pietro  - Giovenale Elena Ford Fiesta R...       Rally3
# 99   #115    Bariani Gianluigi  - Ferrazzi M. Peugeot 206 RC           A7
# 100  #119        Fornalé D.  - Albertini I. Opel Astra G OPC           N3
# 101  #149  Signorotto Bryan  - Favero Giulia Peugeot 106 ...  N1 Under 25
# 102  #138  Dalla Vecchia Corrado  - Gelio P. Opel Corsa A...           A6
#
#      ss_time  ss
# 0     7:00.3   1
# 1     7:00.6   1
# 2     7:03.0   1
# 3     7:03.4   1
# 4     7:06.8   1
# ..       ...  ..
# 98    9:55.0   4
# 99   10:03.2   4
# 100  10:10.5   4
# 101  10:34.2   4
# 102  11:27.0   4
#
# [454 rows x 5 columns]

# %%
rally4 = rally2023_stages[rally2023_stages['Gr/Cl'].str.contains('Rally4')]
rally4 = rally4.drop(['Pos.','Diff','Speed'], axis=1)
stages = rally4.sort_values(by=['ss','ss_time'])
stages['cou']= stages.groupby(['ss']).cumcount()+1
stages
# Out:
#        No                                               Crew            Gr/Cl  \
# 121   #79  Stella Manuele  - Refondini Sara Peugeot 208 R...           Rally4
# 35    #74  Marchioro Nicolò  - Marchetti M. Peugeot 208 R...           Rally4
# 38    #75  Martinis Fabrizio  - Boi Valentina Peugeot 208...           Rally4
# 43    #91  Strabello Stefano  - Pozzan V. Peugeot 208 Rally4           Rally4
# 45    #80  Pesavento Davide  - Frigo Marco Peugeot 208 Ra...  Rally4 Under 25
# ..    ...                                                ...              ...
# 82    #99      Foffano Cristian  - Silvi Luca Peugeot 208 R2           Rally4
# 85    #87  Cianfriglia Diego  - Mazzini Mirco Peugeot 208 R2           Rally4
# 89   #105    Merazzi Andrea  - Argenta Nicola Peugeot 208 R2           Rally4
# 90   #108     Pignani Elia  - Podeschi A. Ford Fiesta Rally4           Rally4
# 94   #106  Gava Antonucci F.  - Silotto D. Peugeot 208 Ra...           Rally4
#
#      ss_time  ss  cou
# 121  10:07.3   1    1
# 35    7:49.0   1    2
# 38    7:51.3   1    3
# 43    7:56.4   1    4
# 45    7:58.9   1    5
# ..       ...  ..  ...
# 82    8:55.3   4   21
# 85    9:00.8   4   22
# 89    9:10.1   4   23
# 90    9:13.4   4   24
# 94    9:20.9   4   25
#
# [121 rows x 6 columns]

# %%
stages = stages.drop('Gr/Cl', axis=1)
#stages['cou'] = stages['cou'].astype(int)
stages2 = stages.set_index(['No', 'Crew', 'ss'], drop=True).unstack('ss', fill_value="_")
stages2 = stages2.fillna('-')
#stages2['cou'] = stages2['cou'].astype(int)
stages2.to_csv('Rally4_Prealpi_2022.csv')
stages2
# Out:
#                                                          ss_time          \
# ss                                                             1       2
# No   Crew
# #100 Cappellati Rudi  - Merco Cristina Peugeot 208 R2     8:10.5  7:55.7
# #101 Callegaro Riccardo  - Faustini A. Peugeot 208 R2     8:39.0  8:32.9
# #102 Pagnan Alex  - Mondin Livio Peugeot 208 Rally4       8:06.4  7:57.9
# #103 Vigna Claudio  - Chittaro Tecla Ford Fiesta R2       9:41.4  8:54.6
# #104 Puppato Alberto  - Barison Michele Peugeot 208 ...   8:37.8  8:03.5
# #105 Merazzi Andrea  - Argenta Nicola Peugeot 208 R2      8:53.2  8:37.1
# #106 Gava Antonucci F.  - Silotto D. Peugeot 208 Rally4   9:35.3  9:01.4
# #107 Gozzoli Stefano  - Gelmini Bruno Peugeot 208 R2      8:38.0  8:12.0
