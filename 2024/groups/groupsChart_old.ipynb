# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import glob

f = 'greek_rallies_2023_stages_times.csv'
# Out:
# /home/ilias/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
data = pd.read_csv(f)
data2 = data[data['Gr/Cl'].str.startswith('C')]
data2
# Out:
#           Crew  Gr/Cl  ss     Race       date surface   competition  cou  \
# 0     Peroulak     C2   1  Achaios  24/9/2023  Tarmac           Cup    1
# 1     Koukeas      C1   1  Achaios  24/9/2023  Tarmac           Cup    2
# 3     Karathan  C5 F2   1  Achaios  24/9/2023  Tarmac           Cup    4
# 4     Daskalop     C2   1  Achaios  24/9/2023  Tarmac           Cup    5
# 5     Dermas V  C3 F2   1  Achaios  24/9/2023  Tarmac           Cup    6
# ...        ...    ...  ..      ...        ...     ...           ...  ...
# 2421  Yiangou      C2   5  Stereas   4/6/2023  Gravel  Championship   23
# 2422  Andrikop  C5 F2   5  Stereas   4/6/2023  Gravel  Championship   24
# 2423  Vassilak     C1   5  Stereas   4/6/2023  Gravel  Championship   25
# 2424  Giokaris  C6 F2   5  Stereas   4/6/2023  Gravel  Championship   26
# 2425  Halkias   C3 F2   5  Stereas   4/6/2023  Gravel  Championship   27
#
#       time_SS_sec  min_time         SS.
# 0          392.82    392.82  Achaios_01
# ...

# %%
data2['GroupC'] = data2['Gr/Cl'].str[:2]
data2
# Out:
# /tmp/ipykernel_9027/1547613874.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['GroupC'] = data2['Gr/Cl'].str[:2]
#           Crew  Gr/Cl  ss     Race       date surface   competition  cou  \
# 0     Peroulak     C2   1  Achaios  24/9/2023  Tarmac           Cup    1
# 1     Koukeas      C1   1  Achaios  24/9/2023  Tarmac           Cup    2
# 3     Karathan  C5 F2   1  Achaios  24/9/2023  Tarmac           Cup    4
# 4     Daskalop     C2   1  Achaios  24/9/2023  Tarmac           Cup    5
# 5     Dermas V  C3 F2   1  Achaios  24/9/2023  Tarmac           Cup    6
# ...        ...    ...  ..      ...        ...     ...           ...  ...
# 2421  Yiangou      C2   5  Stereas   4/6/2023  Gravel  Championship   23
# ...

# %%
sns.boxplot(x="GroupC", y="time_SS_sec", data=(data2))

plt.show()

# %%
data2
# Out:
#           Crew  Gr/Cl  ss     Race       date surface   competition  cou  \
# 0     Peroulak     C2   1  Achaios  24/9/2023  Tarmac           Cup    1
# 1     Koukeas      C1   1  Achaios  24/9/2023  Tarmac           Cup    2
# 3     Karathan  C5 F2   1  Achaios  24/9/2023  Tarmac           Cup    4
# 4     Daskalop     C2   1  Achaios  24/9/2023  Tarmac           Cup    5
# 5     Dermas V  C3 F2   1  Achaios  24/9/2023  Tarmac           Cup    6
# ...        ...    ...  ..      ...        ...     ...           ...  ...
# 2421  Yiangou      C2   5  Stereas   4/6/2023  Gravel  Championship   23
# 2422  Andrikop  C5 F2   5  Stereas   4/6/2023  Gravel  Championship   24
# 2423  Vassilak     C1   5  Stereas   4/6/2023  Gravel  Championship   25
# 2424  Giokaris  C6 F2   5  Stereas   4/6/2023  Gravel  Championship   26
# 2425  Halkias   C3 F2   5  Stereas   4/6/2023  Gravel  Championship   27
#
#       time_SS_sec  min_time         SS. GroupC
# ...

# %%
figsize=(140, 140)
exp_plot = sns.catplot(data=data2, kind="box", y="time_SS_sec", x='SS.', hue='GroupC')
exp_plot.figure.savefig('output_figure.png',dpi=600)

# %%
sns.violinplot(x="GroupC", y="time_SS_sec", data=(data2[data2['Race']=='Potamies']), native_scale=True,hue='ss')

plt.show()

# %%
sns.violinplot(x="GroupC", y="time_SS_sec", data=(data2), native_scale=False)

plt.show()

# %%
data2a = data2[data2['Race']=='Korinthou']
data2a
# Out:
#           Crew  Gr/Cl  ss       Race        date surface competition  cou  \
# 1371  Ismailos     C2   1  Korinthou  21/10/2023  Gravel         Cup    1
# 1372  Mider  -     C2   1  Korinthou  21/10/2023  Gravel         Cup    2
# 1373  Lefkadit  C3 F2   1  Korinthou  21/10/2023  Gravel         Cup    3
# 1374  Paradiss     C2   1  Korinthou  21/10/2023  Gravel         Cup    4
# 1375  Dimopoul  C4 F2   1  Korinthou  21/10/2023  Gravel         Cup    5
# ...        ...    ...  ..        ...         ...     ...         ...  ...
# 1460  Englezos  C6 F2   3  Korinthou  21/10/2023  Gravel         Cup   23
# 1461  Likomitr  C3 F2   3  Korinthou  21/10/2023  Gravel         Cup   24
# 1462  Sotiropo  C6 F2   3  Korinthou  21/10/2023  Gravel         Cup   25
# 1464  Kotsopou  C3 F2   3  Korinthou  21/10/2023  Gravel         Cup   27
# 1465  Kattis D  C6 F2   3  Korinthou  21/10/2023  Gravel         Cup   28
#
#       time_SS_sec  min_time           SS. GroupC
# ...
