# %%
import urllib.request
from bs4 import BeautifulSoup as soup
import requests
import re
import pandas as pd
import dataframe_image as dfi
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import glob

rallyname = 'Molon-Lave'
raceDate = '31/03/2021'
surface = 'Gravel'
competition = 'Greek Cup'

link = 'https://www.ewrc-results.com/results/88517-rally-sprint-molon-lave-2024/?s='
startat, no_ss=455879, int(3)

canceled = []


stages = [number for number in range(no_ss)]

rally_23 = []
# Out:
# /home/ilias/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
if canceled:
    for j in canceled: stages.remove(j-1)

# %%
for ss in stages:
    val= startat + ss
    ss_a = str(val)
    
    my_url11 = link + ss_a
    req = urllib.request.Request(my_url11, headers={'User-Agent': 'Mozilla/5.0'})
    uClient11 = urllib.request.urlopen(req)
    page_html11 = uClient11.read()
    uClient11.close()
    data = pd.read_html(page_html11)[0]
    data.columns=['Pos.', 'No', 'Crew', 'Gr/Cl','ss_time', 'Diff', 'Speed']
    data['ss']=ss+1
    equal = '=' in data['Pos.'].unique()
    if equal:
        data['Pos.'] = data['Pos.'].replace('=', method='ffill')
        data['Pos.'] = data['Pos.'].astype(str).astype(float)
    #print(data.dtypes)
    #print(data)
    rally_23.append(data)

# %%
rally2023_stages = pd.concat(rally_23, axis=0)

# %%
rally2023_stages = pd.concat(rally_23, axis=0)
rally2023_stages['Pos.'] = rally2023_stages['Pos.'].astype(int)
#rally2023_stages['No'] = rally2023_stages['No.'].str[1:]
#rally2023_stages.to_csv('03_rally2023.csv', index=False)
rally2023_stages = rally2023_stages.fillna("-")
rally2023_stages = rally2023_stages.rename(columns={'Driver / Co-driver Vehicle': "Crew"})
rally2023_stages['Race'] = rallyname
rally2023_stages['date'] = raceDate
rally2023_stages['surface'] = surface
rally2023_stages['competition'] = competition
rally2023_stages['Crew'] = rally2023_stages['Crew'].str[:14]
rally2023_stages['Gr/Cl'] = rally2023_stages['Gr/Cl'].str[:3]
rally2023_stages = rally2023_stages.sort_values(by=['Race', 'ss'])
rally2023_stages['cou']= rally2023_stages.groupby(['Race', 'ss']).cumcount()+1
rally2023_stages
# Out:
#     Pos.    No            Crew Gr/Cl   ss_time                   Diff  \
# 0      1    #1  Papadimitriou     C1   9:09.65                      -
# 1      2    #3  Paradissis P.     C2   9:30.66        +21.01 +  21.01
# 2      3    #7  Vigopoulos Nik    C2   9:34.15         +24.50 +  3.49
# 3      4   #10  Tzemos K.  - A    C2   9:48.64        +38.99 +  14.49
# 4      5   #12  Tsetsonis Elia    C2   9:52.25         +42.60 +  3.61
# ..   ...   ...             ...   ...       ...                    ...
# 39    40  #123  Palapanoglou I   2 1  12:28.16       +3:30.91 +  0.80
# 40    41  #115  Papandreou A.    3 -  12:46.76      +3:49.51 +  18.60
# 41    42  #122  Votzakis Pavlo   2 2  12:59.45      +4:02.20 +  12.69
# 42    43  #116  Kansos Patrokl   4 2  13:43.22      +4:45.97 +  43.77
# 43    44   #22  Zouras E.  - P   C4/  24:23.34  +15:26.09 +  10:40.12
#
#         Speed  ss        Race        date surface competition  cou
# 0        77.5   1  Molon-Lave  31/03/2021  Gravel   Greek Cup    1
# 1   74.6 1.78   1  Molon-Lave  31/03/2021  Gravel   Greek Cup    2
# 2   74.2 2.07   1  Molon-Lave  31/03/2021  Gravel   Greek Cup    3
# 3   72.3 3.30   1  Molon-Lave  31/03/2021  Gravel   Greek Cup    4
# 4   71.9 3.60   1  Molon-Lave  31/03/2021  Gravel   Greek Cup    5
# ..        ...  ..         ...         ...     ...         ...  ...
# 39  56.9 17.8   3  Molon-Lave  31/03/2021  Gravel   Greek Cup   40
# 40  55.5 19.4   3  Molon-Lave  31/03/2021  Gravel   Greek Cup   41
# 41  54.6 20.5   3  Molon-Lave  31/03/2021  Gravel   Greek Cup   42
# 42  51.7 24.2   3  Molon-Lave  31/03/2021  Gravel   Greek Cup   43
# 43  29.1 78.3   3  Molon-Lave  31/03/2021  Gravel   Greek Cup   44
#
# [151 rows x 13 columns]

# %%
rally2023_stageClass=rally2023_stages.drop(['No', 'Diff', 'Speed', 'ss_time', 'cou', 'date', 'surface', 'competition'], axis=1)
rally2023_stageTimes=rally2023_stages.drop(['No', 'Diff', 'Speed', 'cou', 'date', 'surface', 'competition', 'Pos.'], axis=1)
rally2023_stageClass['Pos.'] = rally2023_stageClass['Pos.'].astype(str)
rally2023_ClassView = rally2023_stageClass.set_index(['Crew','Gr/Cl','ss','Race'], drop=True).unstack('ss')
rally2023_TimeView = rally2023_stageTimes.set_index(['Crew','Gr/Cl', 'ss', 'Race'], drop=True).unstack('ss')
rally2023_ClassView = rally2023_ClassView.fillna("-")
rally2023_TimeView = rally2023_TimeView.fillna("-")
#rally2023_stageClass2 = rally2023_stageClass.loc[((rally2023_stageClass['Group'] == 'RC1') | (rally2023_stageClass['Group'] == 'RC2'))] 
#rally2023_ClassView2 = rally2023_stageClass2.set_index(['No','Crew','Group','ss', 'Race'], drop=True).unstack('ss')
#rally2023_ClassView2 = rally2023_ClassView2.fillna("-")

# %%
rally2023_ClassView.to_csv(str(rallyname) +'_Stages_Classification.csv')
rally2023_TimeView.to_csv(str(rallyname) + '_Stages_Times.csv')

# %%
pd.set_option("display.max_columns", None)

#dfi.export(rally2023_ClassView, (str(rallyname) + '_Stages_Classification.png'))
dfi.export(rally2023_TimeView,'testtt.png')
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[9], line 4
#       1 #pd.set_option("display.max_columns", None)
#       2
#       3 #dfi.export(rally2023_ClassView, (str(rallyname) + '_Stages_Classification.png'))
# ----> 4 dfi.export(rally2023_TimeView,'testtt.png')
#
# File /usr/local/lib/python3.10/dist-packages/dataframe_image/_pandas_accessor.py:147, in export(obj, filename, fontsize, max_rows, max_cols, table_conversion, chrome_path, dpi, use_mathjax)
#     145 pre_limit = Image.MAX_IMAGE_PIXELS
#     146 Image.MAX_IMAGE_PIXELS = None
# --> 147 img_str = converter(html)
#     148 # swap back to original value
#     149 Image.MAX_IMAGE_PIXELS = pre_limit
#
# File /usr/local/lib/python3.10/dist-packages/dataframe_image/converter/browser/base.py:166, in BrowserConverter.run(self, html)
#     156 def run(self, html: str) -> bytes:
#     157     """
#     158     Run the converter on the HTML.
#     159
#    (...)
#     164         bytes: The converted image bytes.
#     165     """
# --> 166     im = self.screenshot(html)
#     167     temp_img = self.crop(im)
#     168     image_bytes = self.finalize_image(temp_img)
#
# File /usr/local/lib/python3.10/dist-packages/dataframe_image/converter/browser/chrome_converter.py:140, in ChromeConverter.screenshot(self, html, ss_width, ss_height)
#     132     args.append(f"--window-size={ss_width},{ss_height}")
#     134 args += [
#     135     "--hide-scrollbars",
#     136     f"--screenshot={str(temp_img)}",
#     137     str(temp_html),
#     138 ]
# --> 140 subprocess.run(
#     141     executable=self.chrome_path, args=args, capture_output=True, check=True
#     142 )
#     143 with open(temp_img, "rb") as f:
#     144     bio = io.BytesIO(f.read())
#
# File /usr/lib/python3.10/subprocess.py:526, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     524     retcode = process.poll()
#     525     if check and retcode:
# --> 526         raise CalledProcessError(retcode, process.args,
#     527                                  output=stdout, stderr=stderr)
#     528 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['--enable-logging', '--disable-gpu', '--headless', '--crash-dumps-dir=/home/ilias/.dataframe_image/tmp78m7pg0t', '--force-device-scale-factor=1', '--window-size=1400,900', '--hide-scrollbars', '--screenshot=/home/ilias/.dataframe_image/tmp78m7pg0t/temp.png', '/home/ilias/.dataframe_image/tmp78m7pg0t/temp.html']' returned non-zero exit status 64.

# %%
rally2023_stages[['time_mm','time_ss']] = rally2023_stages['ss_time'].str.split(':', expand=True)
#rally2023_stages['time_hh']= rally2023_stages['time_hh'].astype(str).astype(int,errors='ignore')
rally2023_stages['time_mm']= rally2023_stages['time_mm'].astype(str).astype(int,errors='ignore')
rally2023_stages['time_ss']= pd.to_numeric(rally2023_stages['time_ss'], errors='coerce')
rally2023_stages['time_SS_sec'] = rally2023_stages['time_mm']*60 + rally2023_stages['time_ss']
rally2023_stages = rally2023_stages.drop(['Pos.', 'No', 'ss_time', 'Diff',  'Speed', 'time_mm', 'time_ss'], axis=1)
rally2023_stages.to_csv('../' + str(rallyname) + '_Stages_Times_Sec.csv',index=False)
rally2023_stages
# Out:
#               Crew Gr/Cl  ss        Race        date surface competition  cou  \
# 0   Papadimitriou     C1   1  Molon-Lave  31/03/2021  Gravel   Greek Cup    1
# 1   Paradissis P.     C2   1  Molon-Lave  31/03/2021  Gravel   Greek Cup    2
# 2   Vigopoulos Nik    C2   1  Molon-Lave  31/03/2021  Gravel   Greek Cup    3
# 3   Tzemos K.  - A    C2   1  Molon-Lave  31/03/2021  Gravel   Greek Cup    4
# 4   Tsetsonis Elia    C2   1  Molon-Lave  31/03/2021  Gravel   Greek Cup    5
# ..             ...   ...  ..         ...         ...     ...         ...  ...
# 39  Palapanoglou I   2 1   3  Molon-Lave  31/03/2021  Gravel   Greek Cup   40
# 40  Papandreou A.    3 -   3  Molon-Lave  31/03/2021  Gravel   Greek Cup   41
# 41  Votzakis Pavlo   2 2   3  Molon-Lave  31/03/2021  Gravel   Greek Cup   42
# 42  Kansos Patrokl   4 2   3  Molon-Lave  31/03/2021  Gravel   Greek Cup   43
# 43  Zouras E.  - P   C4/   3  Molon-Lave  31/03/2021  Gravel   Greek Cup   44
#
#     time_SS_sec
# 0        549.65
# 1        570.66
# 2        574.15
# 3        588.64
# 4        592.25
# ..          ...
# 39       748.16
# 40       766.76
# 41       779.45
# 42       823.22
# 43      1463.34
#
# [151 rows x 9 columns]

# %%
min_value = rally2023_stages.groupby(['Race', 'ss'])['time_SS_sec'].min()
min_value_G = rally2023_stages.groupby(['Race', 'ss', 'Gr/Cl'])['time_SS_sec'].min()
#min_value = pd.DataFrame(min_value)

min_value2 =  pd.DataFrame(min_value)
min_value2_G =  pd.DataFrame(min_value_G)

min_value2_G = min_value2_G.rename(columns={'time_SS_sec' : 'min_time_Gr'})
min_value2 = min_value2.rename(columns={'time_SS_sec' : 'min_time'})
min_value2_G
# Out:
#                      min_time_Gr
# Race       ss Gr/Cl
# Molon-Lave 1  2 1         748.14
#               2 2         641.86
#               3 -         712.72
#               3 2         602.15
#               4 -         741.11
#               4 1         671.01
#               4 2         625.49
#               C1          549.65
#               C2          570.66
#               C3          652.30
#               C4/         647.94
#               C6          655.81
#               RGT         618.72
#               T1          638.82
#            2  2 1         707.33
#               2 2         645.77
#               3 -         713.60
#               3 2         605.54
#               4 -         714.08
#               4 1         668.73
#               4 2         619.53
#               C1          537.82
#               C2          569.58
#               C3          643.76
#               C4/         633.42
#               C6          644.17
#               RGT         606.09
#               T1          636.42
#            3  2 1         743.60
#               2 2         643.87
#               3 -         702.85
#               3 2         613.63
#               4 -         743.70
#               4 1         655.13
#               4 2         625.34
#               C1          537.25
#               C2          563.80
#               C3          657.02
#               C4/         638.48
#               C6          658.95
#               RGT         607.84

# %%
ss_times_F_G = rally2023_stages.merge(min_value2_G, on=['Race', 'ss', 'Gr/Cl'])
ss_times_F = ss_times_F_G.merge(min_value2, on=['Race', 'ss'])
ss_times_F['diff']=ss_times_F['time_SS_sec'] - ss_times_F['min_time']
ss_times_F['diff_G']=ss_times_F['time_SS_sec'] - ss_times_F['min_time_Gr']
ss_times_F['diff_G%']=(ss_times_F['time_SS_sec'] - ss_times_F['min_time_Gr'])/ss_times_F['min_time_Gr']*100
ss_times_F['SS.']=ss_times_F['ss'].apply(lambda x: '{0:0>2}'.format(x))
ss_times_F
# Out:
#                Crew Gr/Cl  ss        Race        date surface competition  \
# 0    Papadimitriou     C1   1  Molon-Lave  31/03/2021  Gravel   Greek Cup
# 1    Paradissis P.     C2   1  Molon-Lave  31/03/2021  Gravel   Greek Cup
# 2    Vigopoulos Nik    C2   1  Molon-Lave  31/03/2021  Gravel   Greek Cup
# 3    Tzemos K.  - A    C2   1  Molon-Lave  31/03/2021  Gravel   Greek Cup
# 4    Tsetsonis Elia    C2   1  Molon-Lave  31/03/2021  Gravel   Greek Cup
# ..              ...   ...  ..         ...         ...     ...         ...
# 146  Kalamaras Teo    3 -   3  Molon-Lave  31/03/2021  Gravel   Greek Cup
# 147  Papandreou A.    3 -   3  Molon-Lave  31/03/2021  Gravel   Greek Cup
# 148  Christou Dimit   2 1   3  Molon-Lave  31/03/2021  Gravel   Greek Cup
# 149  Palapanoglou I   2 1   3  Molon-Lave  31/03/2021  Gravel   Greek Cup
# 150  Nomikos Ioanni   4 -   3  Molon-Lave  31/03/2021  Gravel   Greek Cup
#
#      cou  time_SS_sec  min_time_Gr  min_time    diff  diff_G   diff_G% SS.
# 0      1       549.65       549.65    549.65    0.00    0.00  0.000000  01
# 1      2       570.66       570.66    549.65   21.01    0.00  0.000000  01
# 2      3       574.15       570.66    549.65   24.50    3.49  0.611573  01
# 3      4       588.64       570.66    549.65   38.99   17.98  3.150738  01
# 4      5       592.25       570.66    549.65   42.60   21.59  3.783339  01
# ..   ...          ...          ...       ...     ...     ...       ...  ..
# 146   31       702.85       702.85    537.25  165.60    0.00  0.000000  03
# 147   41       766.76       702.85    537.25  229.51   63.91  9.092979  03
# 148   37       743.60       743.60    537.25  206.35    0.00  0.000000  03
# 149   40       748.16       743.60    537.25  210.91    4.56  0.613233  03
# 150   38       743.70       743.70    537.25  206.45    0.00  0.000000  03
#
# [151 rows x 15 columns]

# %%
Group = 'C6'
#ss_times_WRC = ss_times_F[ss_times_F['Gr/Cl'].str.contains(Group)]
ss_times_WRC = ss_times_F[ss_times_F['Gr/Cl'].str.contains('|'.join(['C6']))]
ss_times_WRC.to_csv('compare' + str(rallyname) + str(Group) + '.csv')
#ss_times_WRC.to_csv('MolonLabe.csv')

# %%
ss_times_F3 =ss_times_WRC.drop(['Gr/Cl','time_SS_sec','cou', 'ss'], axis=1)
#ss_times_F4 = pd.pivot_table(ss_times_F3, values='diff_G', index='Crew', columns=['Race', 'SS.'])
ss_times_F4 = pd.pivot_table(ss_times_F3, values='diff_G', index='Crew', columns=['SS.'])
ss_times_F4
# Out:
# SS.                01     02     03
# Crew
# Athanassopoulo  39.71  41.35  33.08
# Basdelis Giorg   4.96   7.20    NaN
# Haidas Panagio  85.11  80.25  64.05
# Kokkinos Steli   0.00   5.56   6.48
# Mantas Panagio  51.84  58.51  61.97
# Michalopoulos   25.57  33.13  37.66
# Pateas A.  - P   6.77  18.78    NaN
# Sotiropoulos N   1.61   0.00   0.00

# %%
fig,ax = plt.subplots()
fig.set_size_inches(10,8)
Heatmap_ALL = sns.heatmap(ss_times_F4, cmap='coolwarm')
plt.title(rallyname+'\nDiference between C6 Participants and Stage winer (sec)')
plt.savefig("MolonLabe_Heatmap_C6.png")
plt.show()

# %%
bplt=sns.boxplot( y=ss_times_WRC["time_SS_sec"], x=ss_times_WRC["ss"])
plt.savefig(str(rallyname)  + "Boxplot_C6.png")

# %%
#ss_times_F3
fig,ax = plt.subplots()
fig.set_size_inches(10,8)
ss_timesa = pd.pivot_table(ss_times_F3, values='diff_G%', index='Crew', columns=['SS.'])
Heatmap_ = sns.heatmap(ss_timesa, annot=True, fmt=',.0f', cmap='coolwarm')
plt.title(rallyname +'\nDiference between ' + Group + ' Participants and Group Stage winer (%)')
plt.savefig(rallyname + "_C6.jpg")
plt.show()
