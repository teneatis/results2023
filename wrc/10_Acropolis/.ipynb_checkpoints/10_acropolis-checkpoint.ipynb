# %%
import urllib.request
from bs4 import BeautifulSoup as soup
import requests
import re
import pandas as pd
import dataframe_image as dfi
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

rallyname = 'Acropolis'

link = 'https://rally-base.com/2023/eko-acropolis-rally-2023/?ssId='
startat, no_ss=7824, int(15) # starting number of url, count of Special Stages
canceled = []

stages = [number for number in range(no_ss)]


rally_23 = []

# %%
if canceled:
    for j in canceled: stages.remove(j-1)
#print(stages)

# %%
for ss in stages:
    val= startat + ss
    ss_a = str(val)
    my_url11 = link + ss_a
    #print(ss, val, ss_a, "\n", my_url11)
    
    req = urllib.request.Request(my_url11, headers={'User-Agent': 'Mozilla/5.0'})
    uClient11 = urllib.request.urlopen(req)
    page_html11 = uClient11.read()
    uClient11.close()
    data = pd.read_html(page_html11)[1]
   
    data.columns = data.iloc[0]
    data = data[1:]
    data['ss']=ss+1
    #print(data.columns)
    
    equal = '-' in data['Pos.'].unique()
    if equal:
        data['Pos.'] = data['Pos.'].replace('-', method='ffill')
    
    #data.to_csv('05_rally23_SS'+str(ss+1)+'.csv', index=False)

    rally_23.append(data)
# Out:
# /tmp/ipykernel_48671/3485066229.py:20: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   data['Pos.'] = data['Pos.'].replace('-', method='ffill')
# /tmp/ipykernel_48671/3485066229.py:20: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   data['Pos.'] = data['Pos.'].replace('-', method='ffill')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:213, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# KeyError: 'Pos.'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 18
#      15 data['ss']=ss+1
#      16 #print(data.columns)
# ---> 18 equal = '-' in data['Pos.'].unique()
#      19 if equal:
#      20     data['Pos.'] = data['Pos.'].replace('-', method='ffill')
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'Pos.'

# %%
rally2023_stages = pd.concat(rally_23, axis=0)
#rally2023_stages['Pos.'] = rally2023_stages['Pos.'].astype(str).astype(int)
rally2023_stages['No.'] = rally2023_stages['No.'].astype(str).astype(int)
#rally2023_stages.to_csv('03_rally2023.csv', index=False)
rally2023_stages = rally2023_stages.fillna("-")
rally2023_stages = rally2023_stages.rename(columns={'Driver / Co-driver Vehicle': "Crew"})
rally2023_stages['Race'] = rallyname
rally2023_stages['Crew'] = rally2023_stages['Crew'].str[:10]
rally2023_stages = rally2023_stages.sort_values(by=['Race', 'ss'])
rally2023_stages['cou']= rally2023_stages.groupby(['Race', 'ss']).cumcount()+1
rally2023_stages
# Out:
# 0  Pos.  No.        Crew Group     SS time Aver. speed sec/km  \
# 1     1   69  Rovanperä    RC1  00:01:32.9         57.35 0.00
# 2     2    4  Lappi  Esa   RC1  00:01:33.2         57.17 0.20
# 3     3   11  Neuville     RC1  00:01:33.3         57.11 0.27
# 4     4    6  Sordo  Dan   RC1  00:01:33.4         57.04 0.34
# 5     5    8  Tänak  Ott   RC1  00:01:33.6         56.92 0.47
# ..  ...  ...         ...   ...         ...                ...
# 23   22   38  Cachon  A.   RC2  00:06:15.2        173.67 2.25
# 24   24   39  Villanueva   RC2  00:06:16.3        173.16 2.31
# 25   25    9  Serderidis   RC1  00:06:18.5        172.15 2.44
# 26   26   20  Mikkelsen    RC2  00:06:20.3        171.34 2.54
# 27   27   23  Solberg  O   RC2  00:09:02.1       120.20 11.48
#
# 0  Diff.Leader Diff.Prev.  ss       Race  cou
# 1   00:00:00.0 00:00:00.0   1  Acropolis    1
# 2   00:00:00.3 00:00:00.3   1  Acropolis    2
# 3   00:00:00.4 00:00:00.1   1  Acropolis    3
# 4   00:00:00.5 00:00:00.1   1  Acropolis    4
# 5   00:00:00.7 00:00:00.2   1  Acropolis    5
# ..                    ...  ..        ...  ...
# 23  00:00:40.8 00:00:00.0   2  Acropolis   23
# 24  00:00:41.9 00:00:01.1   2  Acropolis   24
# 25  00:00:44.1 00:00:02.2   2  Acropolis   25
# 26  00:00:45.9 00:00:01.8   2  Acropolis   26
# 27  00:03:27.7 00:02:41.8   2  Acropolis   27
#
# [96 rows x 10 columns]

# %%
rally2023_stageClass=rally2023_stages.drop(['Aver. speed sec/km', 'Diff.Leader Diff.Prev.', 'SS time', 'cou'], axis=1)
rally2023_stageTimes=rally2023_stages.drop(['Aver. speed sec/km', 'Diff.Leader Diff.Prev.', 'Pos.', 'cou'], axis=1)
rally2023_ClassView = rally2023_stageClass.set_index(['No.', 'Crew','Group','ss','Race'], drop=True).unstack('ss')
rally2023_TimeView = rally2023_stageTimes.set_index(['No.', 'Crew','Group', 'ss', 'Race'], drop=True).unstack('ss')
rally2023_ClassView = rally2023_ClassView.fillna("-")
rally2023_TimeView = rally2023_TimeView.fillna("-")
rally2023_stageClass2 = rally2023_stageClass.loc[((rally2023_stageClass['Group'] == 'RC1') | (rally2023_stageClass['Group'] == 'RC2'))] 
rally2023_ClassView2 = rally2023_stageClass2.set_index(['No.','Crew','Group','ss', 'Race'], drop=True).unstack('ss')
rally2023_ClassView2 = rally2023_ClassView2.fillna("-")

# %%
rally2023_ClassView.to_csv(str(rallyname) +'_Stages_Classification.csv')
rally2023_TimeView.to_csv(str(rallyname) + '_Stages_Times.csv',index=False)

# %%
pd.set_option("display.max_columns", None)

dfi.export(rally2023_ClassView2, (str(rallyname) + '_Stages_Classification.png'))
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[6], line 3
#       1 pd.set_option("display.max_columns", None)
# ----> 3 dfi.export(rally2023_ClassView2, (str(rallyname) + '_Stages_Classification.png'))
#
# File ~/.local/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:142, in export(obj, filename, fontsize, max_rows, max_cols, table_conversion, chrome_path, dpi, use_mathjax)
#     140 pre_limit = Image.MAX_IMAGE_PIXELS
#     141 Image.MAX_IMAGE_PIXELS = None
# --> 142 img_str = converter(html)
#     143 # swap back to original value
#     144 Image.MAX_IMAGE_PIXELS = pre_limit
#
# File ~/.local/lib/python3.10/site-packages/dataframe_image/converter/browser/base.py:166, in BrowserConverter.run(self, html)
#     156 def run(self, html: str) -> bytes:
#     157     """
#     158     Run the converter on the HTML.
#     159
#    (...)
#     164         bytes: The converted image bytes.
#     165     """
# --> 166     im = self.screenshot(html)
#     167     temp_img = self.crop(im)
#     168     image_bytes = self.finalize_image(temp_img)
#
# File ~/.local/lib/python3.10/site-packages/dataframe_image/converter/browser/chrome_converter.py:138, in ChromeConverter.screenshot(self, html, ss_width, ss_height)
#     130     args.append(f"--window-size={ss_width},{ss_height}")
#     132 args += [
#     133     "--hide-scrollbars",
#     134     f"--screenshot={str(temp_img)}",
#     135     str(temp_html),
#     136 ]
# --> 138 subprocess.run(
#     139     executable=self.chrome_path, args=args, capture_output=True, check=True
#     140 )
#     141 with open(temp_img, "rb") as f:
#     142     bio = io.BytesIO(f.read())
#
# File /usr/lib/python3.10/subprocess.py:526, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     524     retcode = process.poll()
#     525     if check and retcode:
# --> 526         raise CalledProcessError(retcode, process.args,
#     527                                  output=stdout, stderr=stderr)
#     528 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['--enable-logging', '--disable-gpu', '--headless', '--crash-dumps-dir=/home/teneatis/tmp5fqz3lc6', '--force-device-scale-factor=1', '--window-size=1400,900', '--hide-scrollbars', '--screenshot=/home/teneatis/tmp5fqz3lc6/temp.png', '/home/teneatis/tmp5fqz3lc6/temp.html']' returned non-zero exit status 64.

# %%
rally2023_ClassView
# Out:
# 0                              Pos.
# ss                                1   2
# No. Crew       Group Race
# 4   Lappi  Esa RC1   Acropolis    2   7
# 6   Sordo  Dan RC1   Acropolis    4   6
# 7   Loubet  P. RC1   Acropolis    8   -
# 8   Tänak  Ott RC1   Acropolis    5   3
# 9   Serderidis RC1   Acropolis   32  25
# ...                             ...  ..
# 81  Panteli  C RC4   Acropolis   65   -
# 82  Kanellopou RC4   Acropolis   68   -
# 83  Šekuljica  RC5   Acropolis   60   -
# 84  Parellis   RC5   Acropolis   62   -
# 85  Kaltsounis RC4   Acropolis   67   -
#
# [69 rows x 2 columns]

# %%
rally2023_stages[['time_hh', 'time_mm','time_ss']] = rally2023_stages['SS time'].str.split(':', expand=True)
rally2023_stages['time_hh']= rally2023_stages['time_hh'].astype(str).astype(int,errors='ignore')
rally2023_stages['time_mm']= rally2023_stages['time_mm'].astype(str).astype(int,errors='ignore')
rally2023_stages['time_ss']= pd.to_numeric(rally2023_stages['time_ss'], errors='coerce')
rally2023_stages['time_SS_sec'] = rally2023_stages['time_hh']*3600 + rally2023_stages['time_mm']*60 + rally2023_stages['time_ss']
rally2023_stages = rally2023_stages.drop(['Pos.', 'SS time', 'Aver. speed sec/km',  'Diff.Leader Diff.Prev.', 'time_hh', 'time_mm', 'time_ss'], axis=1)
rally2023_stages.to_csv('../' + str(rallyname) + '_Stages_Times_Sec.csv',index=False)
rally2023_stages
# Out:
# 0   No.        Crew Group  ss       Race  cou  time_SS_sec
# 1    69  Rovanperä    RC1   1  Acropolis    1         92.9
# 2     4  Lappi  Esa   RC1   1  Acropolis    2         93.2
# 3    11  Neuville     RC1   1  Acropolis    3         93.3
# 4     6  Sordo  Dan   RC1   1  Acropolis    4         93.4
# 5     8  Tänak  Ott   RC1   1  Acropolis    5         93.6
# ..  ...         ...   ...  ..        ...  ...          ...
# 23   38  Cachon  A.   RC2   2  Acropolis   23        375.2
# 24   39  Villanueva   RC2   2  Acropolis   24        376.3
# 25    9  Serderidis   RC1   2  Acropolis   25        378.5
# 26   20  Mikkelsen    RC2   2  Acropolis   26        380.3
# 27   23  Solberg  O   RC2   2  Acropolis   27        542.1
#
# [96 rows x 7 columns]

# %%
min_value = rally2023_stages.groupby(['Race', 'ss'])['time_SS_sec'].min()
min_value_G = rally2023_stages.groupby(['Race', 'ss', 'Group'])['time_SS_sec'].min()
#min_value = pd.DataFrame(min_value)

min_value2 =  pd.DataFrame(min_value)
min_value2_G =  pd.DataFrame(min_value_G)

min_value2_G = min_value2_G.rename(columns={'time_SS_sec' : 'min_time_Gr'})
min_value2 = min_value2.rename(columns={'time_SS_sec' : 'min_time'})
min_value2_G
# Out:
#                     min_time_Gr
# Race      ss Group
# Acropolis 1  RC1           92.9
#              RC2           95.0
#              RC3          101.7
#              RC4          109.7
#              RC5          115.5
#           2  RC1          334.4
#              RC2          358.4

# %%
ss_times_F_G = rally2023_stages.merge(min_value2_G, on=['Race', 'ss', 'Group'])
ss_times_F = ss_times_F_G.merge(min_value2, on=['Race', 'ss'])
ss_times_F
# Out:
#     No.        Crew Group  ss       Race  cou  time_SS_sec  min_time_Gr  \
# 0    69  Rovanperä    RC1   1  Acropolis    1         92.9         92.9
# 1     4  Lappi  Esa   RC1   1  Acropolis    2         93.2         92.9
# 2    11  Neuville     RC1   1  Acropolis    3         93.3         92.9
# 3     6  Sordo  Dan   RC1   1  Acropolis    4         93.4         92.9
# 4     8  Tänak  Ott   RC1   1  Acropolis    5         93.6         92.9
# ..  ...         ...   ...  ..        ...  ...          ...          ...
# 91   29  Prokop  Ma   RC2   2  Acropolis   22        375.2        358.4
# 92   38  Cachon  A.   RC2   2  Acropolis   23        375.2        358.4
# 93   39  Villanueva   RC2   2  Acropolis   24        376.3        358.4
# 94   20  Mikkelsen    RC2   2  Acropolis   26        380.3        358.4
# 95   23  Solberg  O   RC2   2  Acropolis   27        542.1        358.4
#
#     min_time
# 0       92.9
# 1       92.9
# 2       92.9
# 3       92.9
# 4       92.9
# ..       ...
# 91     334.4
# 92     334.4
# 93     334.4
# 94     334.4
# 95     334.4
#
# [96 rows x 9 columns]

# %%
ss_times_F['diff']=ss_times_F['time_SS_sec'] - ss_times_F['min_time']
ss_times_F['diff%']=(ss_times_F['time_SS_sec'] - ss_times_F['min_time'])/ss_times_F['min_time']*100
ss_times_F['SS.']=ss_times_F['ss'].apply(lambda x: '{0:0>2}'.format(x))
ss_times_F['diff_Gr']=ss_times_F['time_SS_sec'] - ss_times_F['min_time_Gr']
ss_times_F['diff_Gr%']=(ss_times_F['time_SS_sec'] - ss_times_F['min_time_Gr'])/ss_times_F['min_time_Gr']*100
ss_times_F
# Out:
#     No.        Crew Group  ss       Race  cou  time_SS_sec  min_time_Gr  \
# 0    69  Rovanperä    RC1   1  Acropolis    1         92.9         92.9
# 1     4  Lappi  Esa   RC1   1  Acropolis    2         93.2         92.9
# 2    11  Neuville     RC1   1  Acropolis    3         93.3         92.9
# 3     6  Sordo  Dan   RC1   1  Acropolis    4         93.4         92.9
# 4     8  Tänak  Ott   RC1   1  Acropolis    5         93.6         92.9
# ..  ...         ...   ...  ..        ...  ...          ...          ...
# 91   29  Prokop  Ma   RC2   2  Acropolis   22        375.2        358.4
# 92   38  Cachon  A.   RC2   2  Acropolis   23        375.2        358.4
# 93   39  Villanueva   RC2   2  Acropolis   24        376.3        358.4
# 94   20  Mikkelsen    RC2   2  Acropolis   26        380.3        358.4
# 95   23  Solberg  O   RC2   2  Acropolis   27        542.1        358.4
#
#     min_time   diff      diff% SS.  diff_Gr   diff_Gr%
# 0       92.9    0.0   0.000000  01      0.0   0.000000
# 1       92.9    0.3   0.322928  01      0.3   0.322928
# 2       92.9    0.4   0.430571  01      0.4   0.430571
# 3       92.9    0.5   0.538213  01      0.5   0.538213
# 4       92.9    0.7   0.753498  01      0.7   0.753498
# ..       ...    ...        ...  ..      ...        ...
# 91     334.4   40.8  12.200957  02     16.8   4.687500
# 92     334.4   40.8  12.200957  02     16.8   4.687500
# 93     334.4   41.9  12.529904  02     17.9   4.994420
# 94     334.4   45.9  13.726077  02     21.9   6.110491
# 95     334.4  207.7  62.111244  02    183.7  51.255580
#
# [96 rows x 14 columns]

# %%
Group = 'RC1'
ss_times_WRC = ss_times_F[ss_times_F['Group'].str.contains(Group)]
ss_times_WRC
# Out:
#     No.        Crew Group  ss       Race  cou  time_SS_sec  min_time_Gr  \
# 0    69  Rovanperä    RC1   1  Acropolis    1         92.9         92.9
# 1     4  Lappi  Esa   RC1   1  Acropolis    2         93.2         92.9
# 2    11  Neuville     RC1   1  Acropolis    3         93.3         92.9
# 3     6  Sordo  Dan   RC1   1  Acropolis    4         93.4         92.9
# 4     8  Tänak  Ott   RC1   1  Acropolis    5         93.6         92.9
# 5    17  Ogier  S.    RC1   1  Acropolis    6         94.2         92.9
# 6    18  Katsuta  T   RC1   1  Acropolis    7         94.2         92.9
# 7     7  Loubet  P.   RC1   1  Acropolis    8         94.6         92.9
# 8    33  Evans  Elf   RC1   1  Acropolis   12         95.7         92.9
# 9     9  Serderidis   RC1   1  Acropolis   32        103.5         92.9
# 69   11  Neuville     RC1   2  Acropolis    1        334.4        334.4
# 70   17  Ogier  S.    RC1   2  Acropolis    2        337.8        334.4
# 71    8  Tänak  Ott   RC1   2  Acropolis    3        338.3        334.4
# 72   33  Evans  Elf   RC1   2  Acropolis    4        338.6        334.4
# 73   69  Rovanperä    RC1   2  Acropolis    5        339.9        334.4
# 74    6  Sordo  Dan   RC1   2  Acropolis    6        340.8        334.4
# 75    4  Lappi  Esa   RC1   2  Acropolis    7        341.2        334.4
# 76   18  Katsuta  T   RC1   2  Acropolis    8        343.6        334.4
# 77    9  Serderidis   RC1   2  Acropolis   25        378.5        334.4
#
#     min_time  diff      diff% SS.  diff_Gr   diff_Gr%
# 0       92.9   0.0   0.000000  01      0.0   0.000000
# 1       92.9   0.3   0.322928  01      0.3   0.322928
# 2       92.9   0.4   0.430571  01      0.4   0.430571
# 3       92.9   0.5   0.538213  01      0.5   0.538213
# 4       92.9   0.7   0.753498  01      0.7   0.753498
# 5       92.9   1.3   1.399354  01      1.3   1.399354
# 6       92.9   1.3   1.399354  01      1.3   1.399354
# 7       92.9   1.7   1.829925  01      1.7   1.829925
# 8       92.9   2.8   3.013994  01      2.8   3.013994
# 9       92.9  10.6  11.410118  01     10.6  11.410118
# 69     334.4   0.0   0.000000  02      0.0   0.000000
# 70     334.4   3.4   1.016746  02      3.4   1.016746
# 71     334.4   3.9   1.166268  02      3.9   1.166268
# 72     334.4   4.2   1.255981  02      4.2   1.255981
# 73     334.4   5.5   1.644737  02      5.5   1.644737
# 74     334.4   6.4   1.913876  02      6.4   1.913876
# 75     334.4   6.8   2.033493  02      6.8   2.033493
# 76     334.4   9.2   2.751196  02      9.2   2.751196
# 77     334.4  44.1  13.187799  02     44.1  13.187799

# %%
ss_times_WRC
# Out:
#     No.        Crew Group  ss       Race  cou  time_SS_sec  min_time_Gr  \
# 0    69  Rovanperä    RC1   1  Acropolis    1         92.9         92.9
# 1     4  Lappi  Esa   RC1   1  Acropolis    2         93.2         92.9
# 2    11  Neuville     RC1   1  Acropolis    3         93.3         92.9
# 3     6  Sordo  Dan   RC1   1  Acropolis    4         93.4         92.9
# 4     8  Tänak  Ott   RC1   1  Acropolis    5         93.6         92.9
# 5    17  Ogier  S.    RC1   1  Acropolis    6         94.2         92.9
# 6    18  Katsuta  T   RC1   1  Acropolis    7         94.2         92.9
# 7     7  Loubet  P.   RC1   1  Acropolis    8         94.6         92.9
# 8    33  Evans  Elf   RC1   1  Acropolis   12         95.7         92.9
# 9     9  Serderidis   RC1   1  Acropolis   32        103.5         92.9
# 69   11  Neuville     RC1   2  Acropolis    1        334.4        334.4
# 70   17  Ogier  S.    RC1   2  Acropolis    2        337.8        334.4
# 71    8  Tänak  Ott   RC1   2  Acropolis    3        338.3        334.4
# 72   33  Evans  Elf   RC1   2  Acropolis    4        338.6        334.4
# 73   69  Rovanperä    RC1   2  Acropolis    5        339.9        334.4
# 74    6  Sordo  Dan   RC1   2  Acropolis    6        340.8        334.4
# 75    4  Lappi  Esa   RC1   2  Acropolis    7        341.2        334.4
# 76   18  Katsuta  T   RC1   2  Acropolis    8        343.6        334.4
# 77    9  Serderidis   RC1   2  Acropolis   25        378.5        334.4
#
#     min_time  diff      diff% SS.  diff_Gr   diff_Gr%
# 0       92.9   0.0   0.000000  01      0.0   0.000000
# 1       92.9   0.3   0.322928  01      0.3   0.322928
# 2       92.9   0.4   0.430571  01      0.4   0.430571
# 3       92.9   0.5   0.538213  01      0.5   0.538213
# 4       92.9   0.7   0.753498  01      0.7   0.753498
# 5       92.9   1.3   1.399354  01      1.3   1.399354
# 6       92.9   1.3   1.399354  01      1.3   1.399354
# 7       92.9   1.7   1.829925  01      1.7   1.829925
# 8       92.9   2.8   3.013994  01      2.8   3.013994
# 9       92.9  10.6  11.410118  01     10.6  11.410118
# 69     334.4   0.0   0.000000  02      0.0   0.000000
# 70     334.4   3.4   1.016746  02      3.4   1.016746
# 71     334.4   3.9   1.166268  02      3.9   1.166268
# 72     334.4   4.2   1.255981  02      4.2   1.255981
# 73     334.4   5.5   1.644737  02      5.5   1.644737
# 74     334.4   6.4   1.913876  02      6.4   1.913876
# 75     334.4   6.8   2.033493  02      6.8   2.033493
# 76     334.4   9.2   2.751196  02      9.2   2.751196
# 77     334.4  44.1  13.187799  02     44.1  13.187799

# %%
ss_times_F3 =ss_times_WRC.drop(['Group','time_SS_sec','cou', 'ss'], axis=1)
ss_times_F4 = pd.pivot_table(ss_times_F3, values='diff_Gr', 
                                index='Crew', 
                                columns=['Race', 'SS.'])
ss_times_F4
# Out:
# Race       Acropolis
# SS.               01    02
# Crew
# Evans  Elf       2.8   4.2
# Katsuta  T       1.3   9.2
# Lappi  Esa       0.3   6.8
# Loubet  P.       1.7   NaN
# Neuville         0.4   0.0
# Ogier  S.        1.3   3.4
# Rovanperä        0.0   5.5
# Serderidis      10.6  44.1
# Sordo  Dan       0.5   6.4
# Tänak  Ott       0.7   3.9

# %%
Heatmap_ALL = sns.heatmap(ss_times_F4)
plt.title(rallyname+'\nDiference between '+ Group + ' Participants and Stage winer (sec)')
plt.savefig("Heatmap_" + Group + ".png")

# %%
bplt=sns.boxplot( y=ss_times_WRC["time_SS_sec"], x=ss_times_WRC["ss"])
plt.savefig("Boxplot_" + Group + ".png")
# Out:
# /home/teneatis/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/teneatis/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/teneatis/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
ss_timesa = pd.pivot_table(ss_times_WRC, values='diff_Gr%', 
                                index='Crew', 
                                columns=['SS.'])
Heatmap_ = sns.heatmap(ss_timesa, annot=True, fmt=',.0f')
plt.title(rallyname +'\nDiference between ' + Group + ' Participants and Stage winer (%)')
plt.savefig( Group + ".jpg")
