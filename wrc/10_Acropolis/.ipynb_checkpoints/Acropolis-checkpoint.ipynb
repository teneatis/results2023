# %%
import urllib.request
from bs4 import BeautifulSoup as soup
import requests
import re
import pandas as pd
import dataframe_image as dfi
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

rallyname = 'Acropolis'
raceDate = '7-10/9/2023'
surface = 'Gravel'
competition = 'Wrc'

link = 'https://www.ewrc-results.com/results/80243-eko-acropolis-rally-greece-2023/?s='
startat, no_ss=423312, int(1)

canceled = []

stages = [number for number in range(no_ss)]


rally_23 = []

# %%
if canceled:
    for j in canceled: stages.remove(j-1)
#print(stages)

# %%
for ss in range(0,(no_ss)):
    val= startat + ss
    ss_a = str(val)
    my_url11 = link + ss_a
    #print(my_url11)
    req = urllib.request.Request(my_url11, headers={'User-Agent': 'Mozilla/5.0'})
    uClient11 = urllib.request.urlopen(req)
    page_html11 = uClient11.read()
    uClient11.close()
    data = pd.read_html(page_html11)[0]
    data.columns=['Pos.', 'No', 'Crew', 'Gr/Cl','ss_time', 'Diff', 'Speed']
    data['ss']=ss+1
    equal = '=' in data['Pos.'].unique()
    if equal:
        data['Pos.'] = data['Pos.'].replace('=', method='ffill')
        data['Pos.'] = data['Pos.'].astype(str).astype(float)
    #print(data.dtypes)
    #print(data)
    rally_23.append(data)
# Out:
# /tmp/ipykernel_47045/638908188.py:15: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   data['Pos.'] = data['Pos.'].replace('=', method='ffill')

# %%
rally2023_stages = pd.concat(rally_23, axis=0)

# %%
rally2023_stages = pd.concat(rally_23, axis=0)
rally2023_stages['Pos.'] = rally2023_stages['Pos.'].astype(int)
#rally2023_stages['No'] = rally2023_stages['No.'].str[1:]
#rally2023_stages.to_csv('03_rally2023.csv', index=False)
rally2023_stages = rally2023_stages.fillna("-")
rally2023_stages = rally2023_stages.rename(columns={'Driver / Co-driver Vehicle': "Crew"})
rally2023_stages['Race'] = rallyname
rally2023_stages['date'] = raceDate
rally2023_stages['surface'] = surface
rally2023_stages['competition'] = competition
rally2023_stages['Crew'] = rally2023_stages['Crew'].str[:14]
rally2023_stages = rally2023_stages.sort_values(by=['Race', 'ss'])
rally2023_stages['cou']= rally2023_stages.groupby(['Race', 'ss']).cumcount()+1
rally2023_stages
# Out:
#     Pos.   No            Crew  Gr/Cl  ss_time              Diff      Speed  \
# 0      1  #69  Rovanperä Kall  RC1 M   1:32.9                 -       57.4
# 1      2   #4  Lappi Esapekka  RC1 M   1:33.2         +0.3 +0.3  57.2 0.20
# 2      3  #11  Neuville Thier  RC1 M   1:33.3         +0.4 +0.1  57.1 0.27
# 3      4   #6  Sordo Dani - C  RC1 M   1:33.4         +0.5 +0.1  57.0 0.34
# 4      5   #8  Tänak Ott - Jä  RC1 M   1:33.6         +0.7 +0.2  56.9 0.47
# ..   ...  ...             ...    ...      ...               ...        ...
# 64    65  #81  Panteli C. - T    RC4   2:04.3        +31.4 +2.5  42.9 21.2
# 65    66  #78  Papageorgiou L    RC4   2:28.8       +55.9 +24.5  35.8 37.8
# 66    67  #85  Kaltsounis Har    RC4   2:34.5      +1:01.6 +5.7  34.5 41.6
# 67    68  #82  Kanellopoulos     RC4   2:37.2      +1:04.3 +2.7  33.9 43.5
# 68    69  #58  Türkkan Ali -     RC3  11:44.7  +10:11.8 +9:07.5  7.6 413.4
#
#     ss       Race         date surface competition  cou
# 0    1  Acropolis  7-10/9/2023  Gravel         Wrc    1
# 1    1  Acropolis  7-10/9/2023  Gravel         Wrc    2
# 2    1  Acropolis  7-10/9/2023  Gravel         Wrc    3
# 3    1  Acropolis  7-10/9/2023  Gravel         Wrc    4
# 4    1  Acropolis  7-10/9/2023  Gravel         Wrc    5
# ..  ..        ...          ...     ...         ...  ...
# 64   1  Acropolis  7-10/9/2023  Gravel         Wrc   65
# 65   1  Acropolis  7-10/9/2023  Gravel         Wrc   66
# 66   1  Acropolis  7-10/9/2023  Gravel         Wrc   67
# 67   1  Acropolis  7-10/9/2023  Gravel         Wrc   68
# 68   1  Acropolis  7-10/9/2023  Gravel         Wrc   69
#
# [69 rows x 13 columns]

# %%
rally2023_stageClass=rally2023_stages.drop(['No', 'Diff', 'Speed', 'ss_time', 'cou', 'date', 'surface', 'competition'], axis=1)
rally2023_stageTimes=rally2023_stages.drop(['No', 'Diff', 'Speed', 'cou', 'date', 'surface', 'competition', 'Pos.'], axis=1)
rally2023_stageClass['Pos.'] = rally2023_stageClass['Pos.'].astype(str)
rally2023_ClassView = rally2023_stageClass.set_index(['Crew','Gr/Cl','ss','Race'], drop=True).unstack('ss')
rally2023_TimeView = rally2023_stageTimes.set_index(['Crew','Gr/Cl', 'ss', 'Race'], drop=True).unstack('ss')
rally2023_ClassView = rally2023_ClassView.fillna("-")
rally2023_TimeView = rally2023_TimeView.fillna("-")
#rally2023_stageClass2 = rally2023_stageClass.loc[((rally2023_stageClass['Group'] == 'RC1') | (rally2023_stageClass['Group'] == 'RC2'))] 
#rally2023_ClassView2 = rally2023_stageClass2.set_index(['No','Crew','Group','ss', 'Race'], drop=True).unstack('ss')
#rally2023_ClassView2 = rally2023_ClassView2.fillna("-")

# %%
rally2023_ClassView.to_csv(str(rallyname) +'_Stages_Classification.csv')
rally2023_TimeView.to_csv(str(rallyname) + '_Stages_Times.csv')

# %%
pd.set_option("display.max_columns", None)

dfi.export(rally2023_ClassView, (str(rallyname) + '_Stages_Classification.png'))
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[6], line 3
#       1 pd.set_option("display.max_columns", None)
# ----> 3 dfi.export(rally2023_ClassView, (str(rallyname) + '_Stages_Classification.png'))
#
# File ~/.local/lib/python3.10/site-packages/dataframe_image/_pandas_accessor.py:142, in export(obj, filename, fontsize, max_rows, max_cols, table_conversion, chrome_path, dpi, use_mathjax)
#     140 pre_limit = Image.MAX_IMAGE_PIXELS
#     141 Image.MAX_IMAGE_PIXELS = None
# --> 142 img_str = converter(html)
#     143 # swap back to original value
#     144 Image.MAX_IMAGE_PIXELS = pre_limit
#
# File ~/.local/lib/python3.10/site-packages/dataframe_image/converter/browser/base.py:166, in BrowserConverter.run(self, html)
#     156 def run(self, html: str) -> bytes:
#     157     """
#     158     Run the converter on the HTML.
#     159
#    (...)
#     164         bytes: The converted image bytes.
#     165     """
# --> 166     im = self.screenshot(html)
#     167     temp_img = self.crop(im)
#     168     image_bytes = self.finalize_image(temp_img)
#
# File ~/.local/lib/python3.10/site-packages/dataframe_image/converter/browser/chrome_converter.py:138, in ChromeConverter.screenshot(self, html, ss_width, ss_height)
#     130     args.append(f"--window-size={ss_width},{ss_height}")
#     132 args += [
#     133     "--hide-scrollbars",
#     134     f"--screenshot={str(temp_img)}",
#     135     str(temp_html),
#     136 ]
# --> 138 subprocess.run(
#     139     executable=self.chrome_path, args=args, capture_output=True, check=True
#     140 )
#     141 with open(temp_img, "rb") as f:
#     142     bio = io.BytesIO(f.read())
#
# File /usr/lib/python3.10/subprocess.py:526, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     524     retcode = process.poll()
#     525     if check and retcode:
# --> 526         raise CalledProcessError(retcode, process.args,
#     527                                  output=stdout, stderr=stderr)
#     528 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['--enable-logging', '--disable-gpu', '--headless', '--crash-dumps-dir=/home/teneatis/tmpn1c9v1ky', '--force-device-scale-factor=1', '--window-size=1400,900', '--hide-scrollbars', '--screenshot=/home/teneatis/tmpn1c9v1ky/temp.png', '/home/teneatis/tmpn1c9v1ky/temp.html']' returned non-zero exit status 64.

# %%
rally2023_stages[['time_mm','time_ss']] = rally2023_stages['ss_time'].str.split(':', expand=True)
#rally2023_stages['time_hh']= rally2023_stages['time_hh'].astype(str).astype(int,errors='ignore')
rally2023_stages['time_mm']= rally2023_stages['time_mm'].astype(str).astype(int,errors='ignore')
rally2023_stages['time_ss']= pd.to_numeric(rally2023_stages['time_ss'], errors='coerce')
rally2023_stages['time_SS_sec'] = rally2023_stages['time_mm']*60 + rally2023_stages['time_ss']
rally2023_stages = rally2023_stages.drop(['Pos.', 'No', 'ss_time', 'Diff',  'Speed', 'time_mm', 'time_ss'], axis=1)
rally2023_stages.to_csv('../' + str(rallyname) + '_Stages_Times_Sec.csv',index=False)
rally2023_stages
# Out:
#               Crew  Gr/Cl  ss       Race         date surface competition  \
# 0   Rovanperä Kall  RC1 M   1  Acropolis  7-10/9/2023  Gravel         Wrc
# 1   Lappi Esapekka  RC1 M   1  Acropolis  7-10/9/2023  Gravel         Wrc
# 2   Neuville Thier  RC1 M   1  Acropolis  7-10/9/2023  Gravel         Wrc
# 3   Sordo Dani - C  RC1 M   1  Acropolis  7-10/9/2023  Gravel         Wrc
# 4   Tänak Ott - Jä  RC1 M   1  Acropolis  7-10/9/2023  Gravel         Wrc
# ..             ...    ...  ..        ...          ...     ...         ...
# 64  Panteli C. - T    RC4   1  Acropolis  7-10/9/2023  Gravel         Wrc
# 65  Papageorgiou L    RC4   1  Acropolis  7-10/9/2023  Gravel         Wrc
# 66  Kaltsounis Har    RC4   1  Acropolis  7-10/9/2023  Gravel         Wrc
# 67  Kanellopoulos     RC4   1  Acropolis  7-10/9/2023  Gravel         Wrc
# 68  Türkkan Ali -     RC3   1  Acropolis  7-10/9/2023  Gravel         Wrc
#
#     cou  time_SS_sec
# 0     1         92.9
# 1     2         93.2
# 2     3         93.3
# 3     4         93.4
# 4     5         93.6
# ..  ...          ...
# 64   65        124.3
# 65   66        148.8
# 66   67        154.5
# 67   68        157.2
# 68   69        704.7
#
# [69 rows x 9 columns]

# %%
min_value = rally2023_stages.groupby(['Race', 'ss'])['time_SS_sec'].min()
#min_value = pd.DataFrame(min_value)

min_value2 =  pd.DataFrame(min_value)

min_value2 = min_value2.rename(columns={'time_SS_sec' : 'min_time'})
min_value2
# Out:
#               min_time
# Race      ss
# Acropolis 1       92.9

# %%
ss_times_F = rally2023_stages.merge(min_value2, on=['Race', 'ss'])
ss_times_F['diff']=ss_times_F['time_SS_sec'] - ss_times_F['min_time']
ss_times_F['diff%']=(ss_times_F['time_SS_sec'] - ss_times_F['min_time'])/ss_times_F['min_time']*100
ss_times_F['SS.']=ss_times_F['ss'].apply(lambda x: '{0:0>2}'.format(x))
ss_times_F
# Out:
#               Crew  Gr/Cl  ss       Race         date surface competition  \
# 0   Rovanperä Kall  RC1 M   1  Acropolis  7-10/9/2023  Gravel         Wrc
# 1   Lappi Esapekka  RC1 M   1  Acropolis  7-10/9/2023  Gravel         Wrc
# 2   Neuville Thier  RC1 M   1  Acropolis  7-10/9/2023  Gravel         Wrc
# 3   Sordo Dani - C  RC1 M   1  Acropolis  7-10/9/2023  Gravel         Wrc
# 4   Tänak Ott - Jä  RC1 M   1  Acropolis  7-10/9/2023  Gravel         Wrc
# ..             ...    ...  ..        ...          ...     ...         ...
# 64  Panteli C. - T    RC4   1  Acropolis  7-10/9/2023  Gravel         Wrc
# 65  Papageorgiou L    RC4   1  Acropolis  7-10/9/2023  Gravel         Wrc
# 66  Kaltsounis Har    RC4   1  Acropolis  7-10/9/2023  Gravel         Wrc
# 67  Kanellopoulos     RC4   1  Acropolis  7-10/9/2023  Gravel         Wrc
# 68  Türkkan Ali -     RC3   1  Acropolis  7-10/9/2023  Gravel         Wrc
#
#     cou  time_SS_sec  min_time   diff       diff% SS.
# 0     1         92.9      92.9    0.0    0.000000  01
# 1     2         93.2      92.9    0.3    0.322928  01
# 2     3         93.3      92.9    0.4    0.430571  01
# 3     4         93.4      92.9    0.5    0.538213  01
# 4     5         93.6      92.9    0.7    0.753498  01
# ..  ...          ...       ...    ...         ...  ..
# 64   65        124.3      92.9   31.4   33.799785  01
# 65   66        148.8      92.9   55.9   60.172228  01
# 66   67        154.5      92.9   61.6   66.307858  01
# 67   68        157.2      92.9   64.3   69.214209  01
# 68   69        704.7      92.9  611.8  658.557589  01
#
# [69 rows x 13 columns]

# %%
#ss_times_C6 = ss_times_F[ss_times_F['Gr/Cl'].str.contains('|'.join(['C1', 'C2']))]
ss_times_C6 = ss_times_F[ss_times_F['Gr/Cl'].str.contains('RC2')]
ss_times_C6
# Out:
#               Crew Gr/Cl  ss       Race         date surface competition  cou  \
# 8   Mikkelsen Andr   RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc    9
# 9   Gryazin Nikola   RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   10
# 10  Bulacia Marco    RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   11
# 12  Fourmaux Adrie   RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   13
# 13  Rossel Yohan -   RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   14
# 14  Kajetanowicz K   RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   15
# 15  Solberg Oliver   RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   16
# 16  Joona Lauri -    RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   17
# 17  Greensmith Gus   RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   18
# 18  Munster Grégoi   RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   19
# 19  Virves Robert    RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   20
# 20  Linnamäe Georg   RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   21
# 21  Marczyk Mikoła   RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   22
# 22  Pajari Sami -    RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   23
# 23  Gill Gaurav -    RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   24
# 24  Athanassoulas    RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   25
# 25  Cachón Alejand   RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   26
# 28  Hoelbling Luca   RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   29
# 29  Tsouloftas Ale   RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   30
# 30  Prokop Martin    RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   31
# 33  Velanis Vassil   RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   34
# 34  Philippedes Yo   RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   35
# 37  Karellis C. -    RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   38
# 38  Xanthakos Mari   RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   39
# 39  . - Petropoulo   RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   40
# 41  Kechagias Gior   RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   42
# 42  Cărăgui Eugen    RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   43
# 43  Pyck Filip - D   RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   44
# 45  Díaz-Aboitiz M   RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   46
# 46  Villanueva A.    RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   47
# 47  Dolofan Cristi   RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   48
# 52  Campagnoli Gab   RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   53
# 56  Panteli Petros   RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   57
# 63  Vassilakis Geo   RC2   1  Acropolis  7-10/9/2023  Gravel         Wrc   64
#
#     time_SS_sec  min_time  diff      diff% SS.
# 8          95.0      92.9   2.1   2.260495  01
# 9          95.4      92.9   2.5   2.691066  01
# 10         95.7      92.9   2.8   3.013994  01
# 12         96.0      92.9   3.1   3.336921  01
# 13         96.1      92.9   3.2   3.444564  01
# 14         96.1      92.9   3.2   3.444564  01
# 15         96.6      92.9   3.7   3.982777  01
# 16         96.7      92.9   3.8   4.090420  01
# 17         96.9      92.9   4.0   4.305705  01
# 18         96.9      92.9   4.0   4.305705  01
# 19         96.9      92.9   4.0   4.305705  01
# 20         97.0      92.9   4.1   4.413348  01
# 21         97.2      92.9   4.3   4.628633  01
# 22         97.7      92.9   4.8   5.166846  01
# 23         99.2      92.9   6.3   6.781485  01
# 24        100.8      92.9   7.9   8.503767  01
# 25        101.3      92.9   8.4   9.041981  01
# 28        102.7      92.9   9.8  10.548977  01
# 29        103.3      92.9  10.4  11.194833  01
# 30        103.4      92.9  10.5  11.302476  01
# 33        103.6      92.9  10.7  11.517761  01
# 34        103.6      92.9  10.7  11.517761  01
# 37        104.4      92.9  11.5  12.378902  01
# 38        104.9      92.9  12.0  12.917115  01
# 39        105.2      92.9  12.3  13.240043  01
# 41        105.8      92.9  12.9  13.885899  01
# 42        105.8      92.9  12.9  13.885899  01
# 43        106.3      92.9  13.4  14.424112  01
# 45        107.8      92.9  14.9  16.038751  01
# 46        108.3      92.9  15.4  16.576964  01
# 47        108.6      92.9  15.7  16.899892  01
# 52        110.3      92.9  17.4  18.729817  01
# 56        112.8      92.9  19.9  21.420883  01
# 63        121.8      92.9  28.9  31.108719  01

# %%
ss_times_F3 =ss_times_C6.drop(['Gr/Cl','time_SS_sec','cou', 'ss'], axis=1)
ss_times_F4 = pd.pivot_table(ss_times_F3, values='diff', 
                                index='Crew', 
                                columns=['Race', 'SS.'])
ss_times_F4
# Out:
# Race           Acropolis
# SS.                   01
# Crew
# . - Petropoulo      12.3
# Athanassoulas        7.9
# Bulacia Marco        2.8
# Cachón Alejand       8.4
# Campagnoli Gab      17.4
# Cărăgui Eugen       12.9
# Dolofan Cristi      15.7
# Díaz-Aboitiz M      14.9
# Fourmaux Adrie       3.1
# Gill Gaurav -        6.3
# Greensmith Gus       4.0
# Gryazin Nikola       2.5
# Hoelbling Luca       9.8
# Joona Lauri -        3.8
# Kajetanowicz K       3.2
# Karellis C. -       11.5
# Kechagias Gior      12.9
# Linnamäe Georg       4.1
# Marczyk Mikoła       4.3
# Mikkelsen Andr       2.1
# Munster Grégoi       4.0
# Pajari Sami -        4.8
# Panteli Petros      19.9
# Philippedes Yo      10.7
# Prokop Martin       10.5
# Pyck Filip - D      13.4
# Rossel Yohan -       3.2
# Solberg Oliver       3.7
# Tsouloftas Ale      10.4
# Vassilakis Geo      28.9
# Velanis Vassil      10.7
# Villanueva A.       15.4
# Virves Robert        4.0
# Xanthakos Mari      12.0

# %%
Heatmap_ALL = sns.heatmap(ss_times_F4, cmap='coolwarm')
plt.title(rallyname+'\nDiference between C6 Participants and Stage winer (sec)')
#plt.savefig((rallyname) + "Heatmap_C1.png")
# Out:
# Text(0.5, 1.0, 'Acropolis\nDiference between C6 Participants and Stage winer (sec)')

# %%
bplt=sns.boxplot( y=ss_times_C6["time_SS_sec"], x=ss_times_C6["ss"])
# Out:
# /home/teneatis/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/teneatis/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/teneatis/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
ss_timesa = pd.pivot_table(ss_times_C6, values='diff%', 
                                index='Crew', 
                                columns=['SS.'])
Heatmap_ = sns.heatmap(ss_timesa, annot=True, fmt=',.0f', cmap='coolwarm')
plt.title(rallyname +'\nDiference between C1 Participants and Stage winer (%)')
#plt.savefig(rallyname + "C1.jpg")
# Out:
# Text(0.5, 1.0, 'Acropolis\nDiference between C1 Participants and Stage winer (%)')
