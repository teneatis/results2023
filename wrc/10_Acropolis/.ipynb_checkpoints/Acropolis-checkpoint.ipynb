# %%
import urllib.request
from bs4 import BeautifulSoup as soup
import requests
import re
import pandas as pd
import dataframe_image as dfi
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import glob

rallyname = 'Acropolis'
raceDate = '9/2023'
surface = 'Gravel'
competition = 'Wrc'

link = 'https://www.ewrc-results.com/results/80243-eko-acropolis-rally-greece-2023/?s='
startat, no_ss=423312, int(16)

canceled = [12]


stages = [number for number in range(no_ss)]

rally_23 = []

# %%
if canceled:
    for j in canceled: stages.remove(j-1)

# %%
for ss in stages:
    val= startat + ss
    ss_a = str(val)
    
    my_url11 = link + ss_a
    req = urllib.request.Request(my_url11, headers={'User-Agent': 'Mozilla/5.0'})
    uClient11 = urllib.request.urlopen(req)
    page_html11 = uClient11.read()
    uClient11.close()
    data = pd.read_html(page_html11)[0]
    data.columns=['Pos.', 'No', 'Crew', 'Gr/Cl','ss_time', 'Diff', 'Speed']
    data['ss']=ss+1
    equal = '=' in data['Pos.'].unique()
    if equal:
        data['Pos.'] = data['Pos.'].replace('=', method='ffill')
        data['Pos.'] = data['Pos.'].astype(str).astype(float)
    #print(data.dtypes)
    #print(data)
    rally_23.append(data)

# %%
rally2023_stages = pd.concat(rally_23, axis=0)

# %%
rally2023_stages = pd.concat(rally_23, axis=0)
rally2023_stages['Pos.'] = rally2023_stages['Pos.'].astype(int)
#rally2023_stages['No'] = rally2023_stages['No.'].str[1:]
#rally2023_stages.to_csv('03_rally2023.csv', index=False)
rally2023_stages = rally2023_stages.fillna("-")
rally2023_stages = rally2023_stages.rename(columns={'Driver / Co-driver Vehicle': "Crew"})
rally2023_stages['Race'] = rallyname
rally2023_stages['date'] = raceDate
rally2023_stages['surface'] = surface
rally2023_stages['competition'] = competition
rally2023_stages['Crew'] = rally2023_stages['Crew'].str[:14]
rally2023_stages['Gr/Cl'] = rally2023_stages['Gr/Cl'].str[:3]
rally2023_stages = rally2023_stages.sort_values(by=['Race', 'ss'])
rally2023_stages['cou']= rally2023_stages.groupby(['Race', 'ss']).cumcount()+1
rally2023_stages
# Out:
#     Pos.   No            Crew Gr/Cl     ss_time               Diff      Speed  \
# 0      1  #69  Rovanperä Kall   RC1      1:32.9                  -       57.4
# 1      2   #4  Lappi Esapekka   RC1      1:33.2        +0.3 +  0.3  57.2 0.20
# 2      3  #11  Neuville Thier   RC1      1:33.3        +0.4 +  0.1  57.1 0.27
# 3      4   #6  Sordo Dani  -    RC1      1:33.4        +0.5 +  0.1  57.0 0.34
# 4      5   #8  Tänak Ott  - J   RC1      1:33.6        +0.7 +  0.2  56.9 0.47
# ..   ...  ...             ...   ...         ...                ...        ...
# 48    18  #83  Šekuljica Slav   RC5  7:02.0 [N]       +33.9 +  0.0  76.8 3.77
# 49    18  #84  Parellis Junio   RC5  7:02.0 [N]       +33.9 +  0.0  76.8 3.77
# 50    18  #85  Kaltsounis Har   RC4  7:02.0 [N]       +33.9 +  0.0  76.8 3.77
# 51    52   #9  Serderidis Jou   RC1      7:22.9      +54.8 +  20.9  73.2 6.09
# 52    53  #35  Virves Robert    RC2     13:19.6  +6:51.5 +  5:56.7  40.5 45.7
#
#     ss       Race    date surface competition  cou
# 0    1  Acropolis  9/2023  Gravel         Wrc    1
# 1    1  Acropolis  9/2023  Gravel         Wrc    2
# 2    1  Acropolis  9/2023  Gravel         Wrc    3
# 3    1  Acropolis  9/2023  Gravel         Wrc    4
# 4    1  Acropolis  9/2023  Gravel         Wrc    5
# ..  ..        ...     ...     ...         ...  ...
# 48  16  Acropolis  9/2023  Gravel         Wrc   49
# 49  16  Acropolis  9/2023  Gravel         Wrc   50
# 50  16  Acropolis  9/2023  Gravel         Wrc   51
# 51  16  Acropolis  9/2023  Gravel         Wrc   52
# 52  16  Acropolis  9/2023  Gravel         Wrc   53
#
# [918 rows x 13 columns]

# %%
rally2023_stageClass=rally2023_stages.drop(['No', 'Diff', 'Speed', 'ss_time', 'cou', 'date', 'surface', 'competition'], axis=1)
rally2023_stageTimes=rally2023_stages.drop(['No', 'Diff', 'Speed', 'cou', 'date', 'surface', 'competition', 'Pos.'], axis=1)
rally2023_stageClass['Pos.'] = rally2023_stageClass['Pos.'].astype(str)
rally2023_ClassView = rally2023_stageClass.set_index(['Crew','Gr/Cl','ss','Race'], drop=True).unstack('ss')
rally2023_TimeView = rally2023_stageTimes.set_index(['Crew','Gr/Cl', 'ss', 'Race'], drop=True).unstack('ss')
rally2023_ClassView = rally2023_ClassView.fillna("-")
rally2023_TimeView = rally2023_TimeView.fillna("-")
#rally2023_stageClass2 = rally2023_stageClass.loc[((rally2023_stageClass['Group'] == 'RC1') | (rally2023_stageClass['Group'] == 'RC2'))] 
#rally2023_ClassView2 = rally2023_stageClass2.set_index(['No','Crew','Group','ss', 'Race'], drop=True).unstack('ss')
#rally2023_ClassView2 = rally2023_ClassView2.fillna("-")

# %%
rally2023_ClassView.to_csv(str(rallyname) +'_Stages_Classification.csv')
rally2023_TimeView.to_csv(str(rallyname) + '_Stages_Times.csv')

# %%
pd.set_option("display.max_columns", None)

dfi.export(rally2023_ClassView, (str(rallyname) + '_Stages_Classification.png'))

# %%
rally2023_stages[['time_mm','time_ss']] = rally2023_stages['ss_time'].str.split(':', expand=True)
#rally2023_stages['time_hh']= rally2023_stages['time_hh'].astype(str).astype(int,errors='ignore')
rally2023_stages['time_mm']= rally2023_stages['time_mm'].astype(str).astype(int,errors='ignore')
rally2023_stages['time_ss']= pd.to_numeric(rally2023_stages['time_ss'], errors='coerce')
rally2023_stages['time_SS_sec'] = rally2023_stages['time_mm']*60 + rally2023_stages['time_ss']
rally2023_stages = rally2023_stages.drop(['Pos.', 'No', 'ss_time', 'Diff',  'Speed', 'time_mm', 'time_ss'], axis=1)
rally2023_stages.to_csv('../' + str(rallyname) + '_Stages_Times_Sec.csv',index=False)
rally2023_stages
# Out:
#               Crew Gr/Cl  ss       Race    date surface competition  cou  \
# 0   Rovanperä Kall   RC1   1  Acropolis  9/2023  Gravel         Wrc    1
# 1   Lappi Esapekka   RC1   1  Acropolis  9/2023  Gravel         Wrc    2
# 2   Neuville Thier   RC1   1  Acropolis  9/2023  Gravel         Wrc    3
# 3   Sordo Dani  -    RC1   1  Acropolis  9/2023  Gravel         Wrc    4
# 4   Tänak Ott  - J   RC1   1  Acropolis  9/2023  Gravel         Wrc    5
# ..             ...   ...  ..        ...     ...     ...         ...  ...
# 48  Šekuljica Slav   RC5  16  Acropolis  9/2023  Gravel         Wrc   49
# 49  Parellis Junio   RC5  16  Acropolis  9/2023  Gravel         Wrc   50
# 50  Kaltsounis Har   RC4  16  Acropolis  9/2023  Gravel         Wrc   51
# 51  Serderidis Jou   RC1  16  Acropolis  9/2023  Gravel         Wrc   52
# 52  Virves Robert    RC2  16  Acropolis  9/2023  Gravel         Wrc   53
#
#     time_SS_sec
# 0          92.9
# 1          93.2
# 2          93.3
# 3          93.4
# 4          93.6
# ..          ...
# 48          NaN
# 49          NaN
# 50          NaN
# 51        442.9
# 52        799.6
#
# [918 rows x 9 columns]

# %%
min_value = rally2023_stages.groupby(['Race', 'ss'])['time_SS_sec'].min()
min_value_G = rally2023_stages.groupby(['Race', 'ss', 'Gr/Cl'])['time_SS_sec'].min()
#min_value = pd.DataFrame(min_value)

min_value2 =  pd.DataFrame(min_value)
min_value2_G =  pd.DataFrame(min_value_G)

min_value2_G = min_value2_G.rename(columns={'time_SS_sec' : 'min_time_Gr'})
min_value2 = min_value2.rename(columns={'time_SS_sec' : 'min_time'})
min_value2_G
# Out:
#                     min_time_Gr
# Race      ss Gr/Cl
# Acropolis 1  RC1           92.9
#              RC2           95.0
#              RC3          101.7
#              RC4          109.7
#              RC5          115.5
# ...                         ...
#           16 RC1          388.1
#              RC2          405.0
#              RC3            NaN
#              RC4            NaN
#              RC5            NaN
#
# [75 rows x 1 columns]

# %%
ss_times_F_G = rally2023_stages.merge(min_value2_G, on=['Race', 'ss', 'Gr/Cl'])
ss_times_F = ss_times_F_G.merge(min_value2, on=['Race', 'ss'])
ss_times_F['diff']=ss_times_F['time_SS_sec'] - ss_times_F['min_time']
ss_times_F['diff_G']=ss_times_F['time_SS_sec'] - ss_times_F['min_time_Gr']
ss_times_F['diff_G%']=(ss_times_F['time_SS_sec'] - ss_times_F['min_time_Gr'])/ss_times_F['min_time_Gr']*100
ss_times_F['SS.']=ss_times_F['ss'].apply(lambda x: '{0:0>2}'.format(x))
ss_times_F
# Out:
#                Crew Gr/Cl  ss       Race    date surface competition  cou  \
# 0    Rovanperä Kall   RC1   1  Acropolis  9/2023  Gravel         Wrc    1
# 1    Lappi Esapekka   RC1   1  Acropolis  9/2023  Gravel         Wrc    2
# 2    Neuville Thier   RC1   1  Acropolis  9/2023  Gravel         Wrc    3
# 3    Sordo Dani  -    RC1   1  Acropolis  9/2023  Gravel         Wrc    4
# 4    Tänak Ott  - J   RC1   1  Acropolis  9/2023  Gravel         Wrc    5
# ..              ...   ...  ..        ...     ...     ...         ...  ...
# 913  Panteli C.  -    RC4  16  Acropolis  9/2023  Gravel         Wrc   47
# 914  Kanellopoulos    RC4  16  Acropolis  9/2023  Gravel         Wrc   48
# 915  Kaltsounis Har   RC4  16  Acropolis  9/2023  Gravel         Wrc   51
# 916  Šekuljica Slav   RC5  16  Acropolis  9/2023  Gravel         Wrc   49
# 917  Parellis Junio   RC5  16  Acropolis  9/2023  Gravel         Wrc   50
#
#      time_SS_sec  min_time_Gr  min_time  diff  diff_G   diff_G% SS.
# 0           92.9         92.9      92.9   0.0     0.0  0.000000  01
# 1           93.2         92.9      92.9   0.3     0.3  0.322928  01
# 2           93.3         92.9      92.9   0.4     0.4  0.430571  01
# 3           93.4         92.9      92.9   0.5     0.5  0.538213  01
# 4           93.6         92.9      92.9   0.7     0.7  0.753498  01
# ..           ...          ...       ...   ...     ...       ...  ..
# 913          NaN          NaN     388.1   NaN     NaN       NaN  16
# 914          NaN          NaN     388.1   NaN     NaN       NaN  16
# 915          NaN          NaN     388.1   NaN     NaN       NaN  16
# 916          NaN          NaN     388.1   NaN     NaN       NaN  16
# 917          NaN          NaN     388.1   NaN     NaN       NaN  16
#
# [918 rows x 15 columns]

# %%
Group = 'RC4'
ss_times_WRC = ss_times_F[ss_times_F['Gr/Cl'].str.contains(Group)]
ss_times_WRC.to_csv(str(rallyname) + str(Group) + '.csv')
ss_times_WRC
# Out:
#                Crew Gr/Cl  ss       Race    date surface competition  cou  \
# 58   Fontana Matteo   RC4   1  Acropolis  9/2023  Gravel         Wrc   51
# 59   Plagos Ioannis   RC4   1  Acropolis  9/2023  Gravel         Wrc   52
# 60   Chatzimarkos P   RC4   1  Acropolis  9/2023  Gravel         Wrc   54
# 61   Lefkaditis Sav   RC4   1  Acropolis  9/2023  Gravel         Wrc   58
# 62   Kalamaras Teo    RC4   1  Acropolis  9/2023  Gravel         Wrc   63
# ..              ...   ...  ..        ...     ...     ...         ...  ...
# 911  Fontana Matteo   RC4  16  Acropolis  9/2023  Gravel         Wrc   45
# 912  Kalamaras Teo    RC4  16  Acropolis  9/2023  Gravel         Wrc   46
# 913  Panteli C.  -    RC4  16  Acropolis  9/2023  Gravel         Wrc   47
# 914  Kanellopoulos    RC4  16  Acropolis  9/2023  Gravel         Wrc   48
# 915  Kaltsounis Har   RC4  16  Acropolis  9/2023  Gravel         Wrc   51
#
#      time_SS_sec  min_time_Gr  min_time  diff  diff_G   diff_G% SS.
# 58         109.7        109.7      92.9  16.8     0.0  0.000000  01
# 59         110.2        109.7      92.9  17.3     0.5  0.455789  01
# 60         110.4        109.7      92.9  17.5     0.7  0.638104  01
# 61         113.1        109.7      92.9  20.2     3.4  3.099362  01
# 62         120.4        109.7      92.9  27.5    10.7  9.753874  01
# ..           ...          ...       ...   ...     ...       ...  ..
# 911          NaN          NaN     388.1   NaN     NaN       NaN  16
# 912          NaN          NaN     388.1   NaN     NaN       NaN  16
# 913          NaN          NaN     388.1   NaN     NaN       NaN  16
# 914          NaN          NaN     388.1   NaN     NaN       NaN  16
# 915          NaN          NaN     388.1   NaN     NaN       NaN  16
#
# [135 rows x 15 columns]

# %%
ss_times_F3 =ss_times_WRC.drop(['Gr/Cl','time_SS_sec','cou', 'ss'], axis=1)
#ss_times_F4 = pd.pivot_table(ss_times_F3, values='diff_G', index='Crew', columns=['Race', 'SS.'])
ss_times_F4 = pd.pivot_table(ss_times_F3, values='diff_G', index='Crew', columns=['SS.'])
ss_times_F4
# Out:
# SS.               01     02     03     05     06     07     08     10     11  \
# Crew
# Chatzimarkos P   0.7    0.0    0.0   10.2   21.6    0.0   25.1    NaN    NaN
# Fontana Matteo   0.0    1.8   87.2    0.0    0.0   20.6    0.0  133.3    8.4
# Kalamaras Teo   10.7   56.2   87.0   95.2  168.6  177.1  208.9  140.5  140.9
# Kaltsounis Har  44.8  114.9    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Kanellopoulos   47.5  112.7  239.0  313.4  554.4  956.3  396.6    NaN    NaN
# Lefkaditis Sav   3.4    7.5   36.6   29.2    4.0   25.3   21.1    0.0    0.0
# Panteli C.  -   14.6   21.9   32.8   76.1   56.2   60.4   97.2   89.2    NaN
# Papageorgiou L  39.1  108.0  198.4  561.3  533.4  746.2    NaN    NaN    NaN
# Plagos Ioannis   0.5   10.6   43.0  301.3  139.8    NaN    NaN    NaN    NaN
#
# SS.                13     14
# Crew
# Chatzimarkos P    NaN    0.0
# Fontana Matteo    0.0   42.3
# Kalamaras Teo   157.9  149.8
# Kaltsounis Har    NaN  354.9
# Kanellopoulos     NaN  319.1
# Lefkaditis Sav    2.3    2.2
# Panteli C.  -     NaN   77.9
# Papageorgiou L    NaN  305.1
# Plagos Ioannis    NaN   84.0

# %%
fig,ax = plt.subplots()
fig.set_size_inches(30,30)
Heatmap_ALL = sns.heatmap(ss_times_F4, cmap='coolwarm')
plt.title(rallyname+'\nDiference between '+ Group + ' Participants and Stage winer (sec)')
plt.savefig("Heatmap_" + Group + ".png")
plt.show()

# %%
bplt=sns.boxplot( y=ss_times_WRC["time_SS_sec"], x=ss_times_WRC["ss"])
plt.savefig("Boxplot_" + Group + ".png")

# %%
#ss_times_F3
fig,ax = plt.subplots()
fig.set_size_inches(30,17)
ss_timesa = pd.pivot_table(ss_times_F3, values='diff_G%', index='Crew', columns=['SS.'])
Heatmap_ = sns.heatmap(ss_timesa, annot=True, fmt=',.0f', cmap='coolwarm')
plt.title(rallyname +'\nDiference between ' + Group + ' Participants and Group Stage winer (%)')
plt.savefig(rallyname + Group + ".jpg")
plt.show()
