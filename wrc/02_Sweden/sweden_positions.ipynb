# %%
import urllib.request
from bs4 import BeautifulSoup as soup
import requests
import re
import pandas as pd
link = 'https://rally-base.com/2023/rally-sweden-2023/?ssId='
startat, no_ss=7337, int(18) # starting number of url, count of Special Stages
sweden_23 = []

# %%
for ss in range(0,(no_ss)):
    val= startat + ss
    ss_a = str(val)
    my_url11 = link + ss_a
    #print(ss, val, ss_a, "\n", my_url11)
    
    req = urllib.request.Request(my_url11, headers={'User-Agent': 'Mozilla/5.0'})
    uClient11 = urllib.request.urlopen(req)
    page_html11 = uClient11.read()
    uClient11.close()
    data = pd.read_html(page_html11)[1]
        
    data.columns = data.iloc[0]
    data = data[1:]
    data['ss']=ss+1
    #print(data.columns)
    
    equal = '-' in data['Pos.'].unique()
    if equal:
        data['Pos.'] = data['Pos.'].replace('-', method='ffill')
    
    data.to_csv('02_sweden23_SS'+str(ss+1)+'.csv', index=False)

    sweden_23.append(data)

# %%
sweden2023_stages = pd.concat(sweden_23, axis=0)
#sweden2023_stages['Pos.'] = sweden2023_stages['Pos.'].astype(str).astype(int)
sweden2023_stages['No.'] = sweden2023_stages['No.'].astype(str).astype(int)
sweden2023_stages.info()
sweden2023_stages.to_csv('02_sweden2023.csv', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 903 entries, 1 to 45
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Pos.                        903 non-null    object
#  1   No.                         903 non-null    int32
#  2   Driver / Co-driver Vehicle  903 non-null    object
#  3   Group                       903 non-null    object
#  4   SS time                     903 non-null    object
#  5   Aver. speed sec/km          903 non-null    object
#  6   Diff.Leader Diff.Prev.      903 non-null    object
#  7   ss                          903 non-null    int64
# dtypes: int32(1), int64(1), object(6)
# memory usage: 60.0+ KB

# %%
sweden2023_temp=sweden2023_stages.drop(['Group','SS time', 'Aver. speed sec/km', 'Diff.Leader Diff.Prev.'], axis=1)
sweden2023_view = sweden2023_temp.set_index(['No.','Driver / Co-driver Vehicle','ss'], drop=True).unstack('ss')
sweden2023_view
# Out:
# 0                                                      Pos.                  \
# ss                                                       1   2   3   4   5
# No. Driver / Co-driver Vehicle
# 4   Lappi  Esapekka  /  Ferm  Janne  Hyundai i20 N ...    4   3   2   5   3
# 7   Loubet  P.  /  Gilsoul  Nicolas  Ford Puma Rall...    8   7   8   8   2
# 8   Tänak  Ott  /  Järveoja  M.  Ford Puma Rally1 H...    2   2   4   3   4
# 11  Neuville  T.  /  Wydaeghe  M.  Hyundai i20 N Ra...    5   5   6   7   6
# 18  Katsuta  T.  /  Johnston  Aaron  Toyota GR Yari...    6   4   3   1  21
# 20  Solberg  Oliver  /  Edmondson  E.  Škoda Fabia ...   11  13   9  11   7
# 21  Veiby  O.  /  Eriksen  T.  Volkswagen Polo Gti R5    10  14  11  17  19
# 22  Lindholm  Emil  /  Hämäläinen  R.  Škoda Fabia ...   12   9  48  16   8
# 23  Suninen  Teemu  /  Markkula  Mikko  Hyundai i20...   14  10  13  13  45
# 24  Huttunen  Jari  /  Linnaketo  Antti  Škoda Fabi...    9  12  15  15  13
# ...

# %%
sweden2023_temp2a = sweden2023_temp[sweden2023_temp['No.']<30 ]
sweden2023_temp2b = sweden2023_temp[sweden2023_temp['No.']>=68]
sweden2023_temp2 = pd.concat([sweden2023_temp2a, sweden2023_temp2b])
sweden2023_view2 = sweden2023_temp2.set_index(['No.','Driver / Co-driver Vehicle','ss'], drop=True).unstack('ss')
sweden2023_view2
# Out:
# 0                                                      Pos.                  \
# ss                                                       1   2   3   4   5
# No. Driver / Co-driver Vehicle
# 4   Lappi  Esapekka  /  Ferm  Janne  Hyundai i20 N ...    4   3   2   5   3
# 7   Loubet  P.  /  Gilsoul  Nicolas  Ford Puma Rall...    8   7   8   8   2
# 8   Tänak  Ott  /  Järveoja  M.  Ford Puma Rally1 H...    2   2   4   3   4
# 11  Neuville  T.  /  Wydaeghe  M.  Hyundai i20 N Ra...    5   5   6   7   6
# 18  Katsuta  T.  /  Johnston  Aaron  Toyota GR Yari...    6   4   3   1  21
# 20  Solberg  Oliver  /  Edmondson  E.  Škoda Fabia ...   11  13   9  11   7
# 21  Veiby  O.  /  Eriksen  T.  Volkswagen Polo Gti R5    10  14  11  17  19
# 22  Lindholm  Emil  /  Hämäläinen  R.  Škoda Fabia ...   12   9  48  16   8
# 23  Suninen  Teemu  /  Markkula  Mikko  Hyundai i20...   14  10  13  13  45
# 24  Huttunen  Jari  /  Linnaketo  Antti  Škoda Fabi...    9  12  15  15  13
# ...

# %%
linkFinal = 'https://rally-base.com/2023/rally-sweden-2023/'
reqF = urllib.request.Request(linkFinal, headers={'User-Agent': 'Mozilla/5.0'})
uClient = urllib.request.urlopen(reqF)
page_F = uClient.read()
uClient.close()
dataF = pd.read_html(page_F)[2]
        
dataF.columns = dataF.iloc[0]
dataF = dataF[1:]
dataF.columns.values[0] = "F_Pos."
#dataF.rename(columns={'Pos.': 'F_Pos.'})
dataF
# Out:
# 0  F_Pos. No.   NaN                         Driver / Co-driver Vehicle  \
# 1       1   8   1.0  Tänak  Ott /  Järveoja  M.  Ford Puma Rally1 H...
# 2       2  42   3.0  Breen  Craig /  Fulton  James  Hyundai i20 N R...
# 3       3  11   2.0  Neuville  T. /  Wydaeghe  M.  Hyundai i20 N Ra...
# 4       4  69   4.0  Rovanperä  K. /  Halttunen  Jonne  Toyota GR Y...
# 5       5  33   5.0  Evans  Elfyn /  Martin  Scott  Toyota GR Yaris...
# 6       6   7   6.0  Loubet  P. /  Gilsoul  Nicolas  Ford Puma Rall...
# 7       7   4   8.0  Lappi  Esapekka /  Ferm  Janne  Hyundai i20 N ...
# 8       8  20   7.0  Solberg  Oliver /  Edmondson  E.  Škoda Fabia ...
# 9       9  21   9.0   Veiby  O. /  Eriksen  T.  Volkswagen Polo Gti R5
# 10     10  28  10.0  Pajari  Sami /  Mälkönen  Enni  Škoda Fabia RS...
# 11     11  27  11.0  Gryazin  Nikolay /  Aleksandrov  K.  Škoda Fab...
# 12     12  25  12.0  Linnamäe  Georg /  Morgan  James  Hyundai i20 ...
# ...

# %%
#dataF.drop(['Diff.Leader Diff.Prev.'], axis=1)
#swedenStagePosition23 = pd.concat(sweden2023_stages, dataF, ignore_index=True)
#swedenStagePosition23
dataF2 = dataF.drop(dataF.columns[[2, 3, 4, 5, 6, 7]],axis = 1)
dataF2
# Out:
# 0  F_Pos. No.
# 1       1   8
# 2       2  42
# 3       3  11
# 4       4  69
# 5       5  33
# 6       6   7
# 7       7   4
# 8       8  20
# 9       9  21
# 10     10  28
# 11     11  27
# 12     12  25
# 13     13  31
# 14     14  37
# 15     15  23
# 16     16  22
# 17     17  30
# 18     18  29
# 19     19  32
# 20     20  26
# 21     21  36
# 22     22  49
# 23     23  50
# 24     24  52
# 25     25  54
# 26     26  51
# 27     27  46
# 28     28  58
# 29     29  48
# 30     30  60
# 31     31  34
# 32     32  64
# 33     33  59
# 34     34  35
# 35     35  55
# 36     36  61
# 37     37  47
# 38     38  44
# 39     39  45
# 40     40  53
# 41     41  66
# 42     42  65
# 43     43  63
# 44     44  57
# 45     45  62

# %%
dataF2['No.'] = dataF2['No.'].astype(str).astype(int)
#dataF2['F_Pos.'] = dataF2['F_Pos.'].astype(str).astype(int)
swedenStagePosition23 = sweden2023_stages.join(dataF2.set_index('No.'), on='No.', validate='m:1')
swedenStagePosition23
# Out:
# 0  Pos.  No.                         Driver / Co-driver Vehicle Group  \
# 1     1   69  Rovanperä  K.  /  Halttunen  Jonne  Toyota GR ...   RC1
# 2     2    8  Tänak  Ott  /  Järveoja  M.  Ford Puma Rally1 ...   RC1
# 3     3   33  Evans  Elfyn  /  Martin  Scott  Toyota GR Yari...   RC1
# 4     4    4  Lappi  Esapekka  /  Ferm  Janne  Hyundai i20 N...   RC1
# 5     5   11  Neuville  T.  /  Wydaeghe  M.  Hyundai i20 N R...   RC1
# ..  ...  ...                                                ...   ...
# 41   41   64  Otake  Nao  /  Salminen  Marko  Renault Clio R...   RC4
# 42   42    7  Loubet  P.  /  Gilsoul  Nicolas  Ford Puma Ral...   RC1
# 43   43   35  Al-Rashed  Rakan  /  Moscatt  Dale  Škoda Fabi...   RC2
# 44   44   26  Kaur  Egon  /  Viilo  Jakko  Škoda Fabia Rally...   RC2
# 45   45   59  Rensonnet  Tom  /  Dumont  Loïc  Ford Fiesta R...   RC3
#
# 0      SS time Aver. speed sec/km Diff.Leader Diff.Prev.  ss F_Pos.
# ...

# %%
sweden2023_tempRan=swedenStagePosition23.drop(['Group','SS time', 'Aver. speed sec/km', 'Diff.Leader Diff.Prev.'], axis=1)
sweden2023_viewRan = sweden2023_tempRan.set_index(['F_Pos.', 'No.','Driver / Co-driver Vehicle','ss'], drop=True).unstack('ss')
sweden2023_viewRan.sort_values(by=['F_Pos.'])
# Out:
# 0                                                             Pos.          \
# ss                                                              1   2   3
# F_Pos. No. Driver / Co-driver Vehicle
# 1      8   Tänak  Ott  /  Järveoja  M.  Ford Puma Rally1 H...    2   2   4
# 10     28  Pajari  Sami  /  Mälkönen  Enni  Škoda Fabia RS...   12  11  16
# 11     27  Gryazin  Nikolay  /  Aleksandrov  K.  Škoda Fab...   15  18  12
# 12     25  Linnamäe  Georg  /  Morgan  James  Hyundai i20 ...   22  21  20
# 13     31  Bulacia  Marco  /  Vallejo  Diego  Škoda Fabia ...   16  16  14
# 14     37  Bertelli  L.  /  Scattolin  S.  Toyota GR Yaris...   18  15  10
# 15     23  Suninen  Teemu  /  Markkula  Mikko  Hyundai i20...   14  10  13
# 16     22  Lindholm  Emil  /  Hämäläinen  R.  Škoda Fabia ...   12   9  48
# 17     30  Joona  Lauri  /  Shemeikka  T.  Škoda Fabia Ral...   19  22  18
# 18     29  Virves  Robert  /  Magalhães  Hugo  Ford Fiesta...   23  20  21
# ...

# %%
sweden2023_viewRan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 51 entries, (nan, 18, 'Katsuta  T.  /  Johnston  Aaron  Toyota GR Yaris Rally1 Hybrid') to ('9', 21, 'Veiby  O.  /  Eriksen  T.  Volkswagen Polo Gti R5')
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   (Pos., 1)   51 non-null     object
#  1   (Pos., 2)   51 non-null     object
#  2   (Pos., 3)   51 non-null     object
#  3   (Pos., 4)   51 non-null     object
#  4   (Pos., 5)   51 non-null     object
#  5   (Pos., 6)   51 non-null     object
#  6   (Pos., 7)   51 non-null     object
#  7   (Pos., 8)   51 non-null     object
#  8   (Pos., 9)   51 non-null     object
#  9   (Pos., 10)  51 non-null     object
#  10  (Pos., 11)  51 non-null     object
#  11  (Pos., 12)  51 non-null     object
#  12  (Pos., 13)  51 non-null     object
#  13  (Pos., 14)  51 non-null     object
#  14  (Pos., 15)  50 non-null     object
#  15  (Pos., 16)  48 non-null     object
# ...
